# %%
#=============================================================================#
#                                      Input                                  #
#=============================================================================#

BASE_PATH = "C:/Users/aelek/source/antoniaelek/fantasy-premier-league/"
SEASON = "2018-19"
GWCNT = 5
RANGE_START = 1
RANGE_END = -1

# %%
#=============================================================================#
#                                    Functions                                #
#=============================================================================#

import pandas

def get_player_data(player, season="2018-19", range_start=1, range_end=-1):
    pl_path = BASE_PATH + "data/" + season + "/players/" + player + "/gw.csv"
    # Get player dataset
    df = pandas.read_csv(open(pl_path,'r'))
    x = [x*1 for x in range(1,len(df)+1)]
    df['gw'] = x
    if range_end == -1:
        range_end = len(df['gw'])

    df = df[range_start-1:range_end]
    return df

def map_position(row):
    if row['element_type'] == 1:
        val = 'Goalkeeper'
    elif row['element_type'] == 2:
        val = 'Defender'
    elif row['element_type'] == 3:
        val = 'Midfielder'
    else:
        val = 'Forward'
    return val

def map_status(row):
    if row['status'] == 'a':
        val = 'Avaliable'
    elif row['status'] == 'd':
        val = 'Questionable'
    elif row['status'] == 'i':
        val = 'Injured'
    elif row['status'] == 's':
        val = 'Suspended'
    else:
        val = 'Unknown'
    return val

def map_team(row):
    if row['team_code'] == 3:
        val = 'Arsenal'
    elif row['team_code'] == 91:
        val = 'Bournemouth'
    elif row['team_code'] == 36:
        val = 'Brighton'
    elif row['team_code'] == 90:
        val = 'Burnley'
    elif row['team_code'] == 97:
        val = 'Cardiff'
    elif row['team_code'] == 8:
        val = 'Chelsea'
    elif row['team_code'] == 31:
        val = 'Crystal Palace'
    elif row['team_code'] == 11:
        val = 'Everton'
    elif row['team_code'] == 54:
        val = 'Fulham'
    elif row['team_code'] == 38:
        val = 'Huddersfield'
    elif row['team_code'] == 13:
        val = 'Leicester'
    elif row['team_code'] == 14:
        val = 'Liverpool'
    elif row['team_code'] == 43:
        val = 'Man City'
    elif row['team_code'] == 1:
        val = 'Man Utd'
    elif row['team_code'] == 4:
        val = 'Newcastle'
    elif row['team_code'] == 20:
        val = 'Southampton'
    elif row['team_code'] == 6:
        val = 'Spurs'
    elif row['team_code'] == 57:
        val = 'Watford'
    elif row['team_code'] == 21:
        val = 'West Ham'
    elif row['team_code'] == 39:
        val = 'Wolves'
    else:
        val = 'Unknown'
    return val

def map_code_to_str(row):
    return str(row['code'])

def get_cumulative_data(season="2018-19"):
    # all data csv path
    all_path = BASE_PATH + "data/" + season + "/players_raw.csv"

    # Get all players
    alldf = pandas.read_csv(all_path)
    alldf["code2"] = alldf.apply(map_code_to_str, axis=1)
    alldf["lower_name"] = alldf["first_name"].str.lower() + " " + alldf["second_name"].str.lower()
    alldf["full_name"] = alldf["first_name"] + " " + alldf["second_name"]
    alldf["full_name2"] = alldf["first_name"] + "_" + alldf["second_name"]
    alldf["full_name3"] = alldf["first_name"] + " " + alldf["second_name"] + "_" + alldf["code2"]
    alldf["price"] = alldf["now_cost"]/10
    alldf["position"] = alldf.apply(map_position, axis=1)
    alldf["avail_status"] = alldf.apply(map_status, axis=1)
    alldf["team_name"] = alldf.apply(map_team, axis=1)
    alldf['basic_stats'] = round((alldf['total_points'] + alldf['bonus']) / (alldf['minutes']/90) + alldf['points_per_game'] + alldf['dreamteam_count'],2)
    alldf['quality'] = round((alldf['creativity'] + alldf['ict_index'] + alldf['threat']) * 0.2 + alldf['influence'] * 0.2 + alldf['form'] * 0.6,2)
    alldf['in_game_stats'] = round((alldf['goals_scored'] - alldf['goals_conceded'] + alldf['assists'] + alldf['clean_sheets'] + alldf['saves'] - alldf['own_goals'] - alldf['penalties_missed'] + alldf['penalties_saved'] - alldf['yellow_cards'] * 0.2 - alldf['red_cards'] * 0.6) / (alldf['minutes']/90),2)
    alldf['popularity'] = round(((alldf['transfers_in'] - alldf['transfers_out']) + (alldf['transfers_in_event'] - alldf['transfers_out_event']) + alldf['selected_by_percent'] * 50000)/1000,2)
    
    return alldf

# def get_player_photo(name):
#     photo = get_player_photo_id(name)
#     return "https://platform-static-files.s3.amazonaws.com/premierleague/photos/players/110x140/p" + photo + ".png"

# def get_player_photo_id(name):
#     # Get all players data
#     alldf = get_cumulative_data()
    
#     # Get photo url for given player
#     fdf = alldf[alldf["lower_name"]==name.lower()]
#     return fdf["photo"].iloc[0][:-4]

# %%
#=============================================================================#
#                                Data retrieval                               #
#=============================================================================#

ALLDF = get_cumulative_data(season=SEASON)
PLAYERS = ALLDF["full_name"].values.tolist()
PLAYERS2 = ALLDF["full_name2"].values.tolist()
PLAYERS3 = ALLDF["full_name3"].values.tolist()
ALLDF = ALLDF.set_index(['full_name3'])

#PLAYERS=['Danny Ward', 'Eden Hazard', 'Mohamed Salah', 'David De Gea']
#PLAYERS2=['Danny_Ward', 'Eden_Hazard', 'Mohamed_Salah', 'David_De Gea']

# i=130
# PLAYER=PLAYERS[i]
# PLAYER2=PLAYERS2[i]
# PLAYER3=PLAYERS3[i]

# val = (ALLDF[ALLDF.index.str.startswith(PLAYER3)])
# print(val.index[0])

# val = (ALLDF[ALLDF.index.str.startswith(PLAYER3)])
# print(val['code'])

# val
# print("val is " + str(type(val)) + " of len: " + str(len(val)))
# print("curr index of val is " + str(type(val.index[0])) + " with value: " + str(val.index[0]))
# print("val['price'] is " + str(type(val['price'][0])) + " with value: " + str(val['price'][0]))

# %%
#=============================================================================#
#                                     Stats                                   #
#=============================================================================#

for i in range(0,len(PLAYERS)):
    PLAYER=PLAYERS[i]
    PLAYER2=PLAYERS2[i]
    PLAYER3=PLAYERS3[i]
    
    val = (ALLDF[ALLDF.index.str.startswith(PLAYER3)])
    #print(val.index[0])
    
    md_file=BASE_PATH + 'docs/assets/bokeh/player_stats/' + PLAYER3 + '_text.html'
        
    with open(md_file, 'w', encoding='utf8') as f:
        f.write('<head><style>' + 
                'body, table, td { font-family: "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif; color: #444; line-height: 0.8; font-size: 12px; } ' + 
                'h1, h2, h3, h4, h5, h6 { margin: 10px 0 5px 0 !important; font-family: Helvetica, Arial, sans-serif; color: #34465d; font-weight: bold; line-height: 0.8; } ' +
                'h1{font-size:20px} h2{font-size:18px} h3{font-size:16px} h4{font-size:14px} h5{font-size:12px} h6{font-size:12px} ' + 
                'td{ padding: 2px 5px 2px 5px; }</style></head>')
        f.write('<body><h1>' + val['full_name'][0] + '</h1>')                         
        f.write('<table><tr><td colspan=2><h3>' + str(val['position'][0])     + ', ' + str(val['price'][0]) + ' £</h3></td><td></td></tr>')
        f.write('<tr><td><b>Team: </b>'              + str(val['team_name'][0])    + '</td>' +                      
                           '<td><b>Status:</b> ' + str(val['avail_status'][0]) + '</td></tr>')

        f.write('<tr><td colspan=2><h3>Basic Stats</h3></td><td id="basic_stats" style="display:none;">'+ str(val['basic_stats'][0]) +'</td><td></td></tr>')
        f.write('<tr><td><b>Minutes played:</b> '      + str(val['minutes'][0])              + '</td>' +  
                           '<td><b>Total Points:</b> '        + str(val['total_points'][0])    + '</td></tr>' +  
                       '<tr><td><b>Bonus Points:</b> '        + str(val['bonus'][0])           + '</td>' +          
                           '<td><b>BPS:</b> '                 + str(val['bps'][0])             + '</td></tr>' +   
                       '<tr><td><b>Points Per Game:</b> '     + str(val['points_per_game'][0]) + '</td>' +         
                           '<td><b>Times in Dream Team:</b> ' + str(val['dreamteam_count'][0]) + '</td></tr>')      

        f.write('<tr><td colspan=2><h3>Quality</h3></td><td id="quality" style="display:none;">'+ str(val['quality'][0]) +'</td><td></td></tr>')
        f.write('<tr><td><b>Creativity:</b> ' + str(val['creativity'][0])      + '</td>' +       
                           '<td><b>Form:</b> '       + str(val['form'][0])       + '</td></tr>' +       
                       '<tr><td><b>ICT index:</b> '  + str(val['ict_index'][0])  + '</td>' +         
                           '<td><b>Threat:</b> '     + str(val['threat'][0])     + '</td></tr>' +                   
                       '<tr><td><b>Influence:</b> '  + str(val['influence'][0])  + '</td>'+
                           '<td></td></tr>')

        f.write('<tr><td colspan=2><h3>In-Game Stats</h3></td><td id="in_game_stats" style="display:none;">'+ str(val['in_game_stats'][0]) +'</td><td></td></tr>')
        f.write('<tr><td><b>Goals Scored:</b> '         + str(val['goals_scored'][0])          + '</td>' +  
                            '<td><b>Assists:</b> '             + str(val['assists'][0])          + '</td></tr>' +     
                        '<tr><td><b>Goals Conceded:</b> '      + str(val['goals_conceded'][0])   + '</td>' + 
                            '<td><b>Clean Sheets:</b> '        + str(val['clean_sheets'][0])     + '</td></tr>' +         
                        '<tr><td><b>Saves:</b> '               + str(val['saves'][0])            + '</td>' +
                            '<td><b>Own Goals:</b> '           + str(val['own_goals'][0])        + '</td></tr>' + 
                        '<tr><td><b>Penalties Missed:</b> '    + str(val['penalties_missed'][0]) + '</td>' +    
                            '<td><b>Penalties Saved:</b> '     + str(val['penalties_saved'][0])  + '</td></tr>' +
                        '<tr><td><b>Yellow Cards:</b> '        + str(val['yellow_cards'][0])     + '</td>' +
                            '<td><b>Red Cards:</b> '           + str(val['red_cards'][0])        + '</td></tr>')

        f.write('<tr><td colspan=2><h3>Popularity</td><td id="popularity" style="display:none;">'+ str(val['popularity'][0]) +'</td><td></td></tr>')
        f.write('<tr><td><b>Transfers In:</b> '        + str(val['transfers_in'][0])       + '</td>' +                  
                    '<td><b>Transfers Out:</b> '       + str(val['transfers_out'][0])       + '</td></tr>' +                           
                '<tr><td><b>GW Transfers In:</b> '     + str(val['transfers_in_event'][0])  + '</td>' +        
                    '<td><b>GW Transfers Out:</b> '    + str(val['transfers_out_event'][0]) + '</td></tr>' +    
                '<tr><td><b>Selected by:</b> '       + str(val['selected_by_percent'][0]) + '% </td>' +
                    '<td></td></tr></table></body>')

# %%
#=============================================================================#
#                                     Plots                                   #
#=============================================================================#

from bokeh.plotting import figure, output_file, show
from bokeh.layouts import gridplot, widgetbox, layout, row, column
from bokeh.models import CustomJS, ColumnDataSource, Range1d, Plot, LinearAxis, Grid
from bokeh.models.glyphs import ImageURL
from bokeh.models.widgets import Button, RadioButtonGroup, Select, RangeSlider
from bokeh.io import *
from IPython.display import display, Markdown
from IPython.display import HTML, display
from matplotlib import pyplot as plt

ALLDF = get_cumulative_data(season=SEASON)
PLAYERS = ALLDF["full_name"].values.tolist()
PLAYERS2 = ALLDF["full_name2"].values.tolist()
PLAYERS3 = ALLDF["full_name3"].values.tolist()

for i in range(0,len(PLAYERS)):
    PLAYER=PLAYERS[i]
    PLAYER2=PLAYERS2[i]
    PLAYER3=PLAYERS3[i]
    
#     if PLAYER != 'David De Gea':
#        continue
    
    # get plots data
    val = get_player_data(player=PLAYER2)
    source = ColumnDataSource(data=dict(x=val['gw'], y_value=val['value']/10, y_pts=val['total_points'], y_mins=val['minutes'], y_influence=val['influence']))
    
    # plots
    p_price = figure(y_axis_label='£', tools="", x_range=(1, GWCNT))
    p_price.line('x', 'y_value', source=source, line_width=2)

    p_pts = figure(y_axis_label='pts', tools="", x_range=(1, GWCNT))
    p_pts.line('x', 'y_pts', source=source, line_width=2)

    p_mins = figure(y_axis_label='mins', tools="", x_range=(1, GWCNT), y_range=(0, 100))
    p_mins.line('x', 'y_mins', source=source, line_width=2)

    p_ict = figure(x_axis_label='gw', y_axis_label='influence', tools="", x_range=(1, GWCNT))
    p_ict.line('x', 'y_influence', source=source, line_width=2)

    p = gridplot([p_price, p_pts, p_mins, p_ict],ncols=1, plot_width=300, plot_height=110, toolbox=None, toolbar_options={'logo': None})

    fig = row(p)
#     output_notebook()
#     show(fig)
    output_file(BASE_PATH + '/docs/assets/bokeh/player_stats/' + PLAYER3 + '.html')
#     print(PLAYER3)
    save(fig)

# %%
print(len(PLAYERS),len(PLAYERS2),len(PLAYERS3))
for i in range(0,len(PLAYERS)):
    PLAYER=PLAYERS[i]
    PLAYER2=PLAYERS2[i]
    PLAYER3=PLAYERS3[i]
    print("%30s %30s %30s\n" % (PLAYER, PLAYER2, PLAYER3))
# Out:
# 537 537 537
#                      Petr Cech                      Petr_Cech                Petr Cech_11334
#
#                     Bernd Leno                     Bernd_Leno               Bernd Leno_80201
#
#              Laurent Koscielny              Laurent_Koscielny        Laurent Koscielny_51507
#
#                Héctor Bellerín                Héctor_Bellerín          Héctor Bellerín_98745
#
#                  Nacho Monreal                  Nacho_Monreal            Nacho Monreal_38411
#
#                    Rob Holding                    Rob_Holding             Rob Holding_156074
#
#               Shkodran Mustafi               Shkodran_Mustafi         Shkodran Mustafi_69140
#
#                 Sead Kolasinac                 Sead_Kolasinac          Sead Kolasinac_111457
#
#        Konstantinos Mavropanos        Konstantinos_Mavropanos Konstantinos Mavropanos_233963
#
#           Stephan Lichtsteiner           Stephan_Lichtsteiner     Stephan Lichtsteiner_27335
#
#      Sokratis Papastathopoulos      Sokratis_Papastathopoulos Sokratis Papastathopoulos_39476
#
#                     Mesut Özil                     Mesut_Özil               Mesut Özil_37605
#
#                   Aaron Ramsey                   Aaron_Ramsey             Aaron Ramsey_41792
#
#                     Alex Iwobi                     Alex_Iwobi              Alex Iwobi_153133
#
#                 Mohamed Elneny                 Mohamed_Elneny          Mohamed Elneny_153256
#
#                   Granit Xhaka                   Granit_Xhaka             Granit Xhaka_84450
#
#             Henrikh Mkhitaryan             Henrikh_Mkhitaryan       Henrikh Mkhitaryan_57249
#
#                   Reiss Nelson                   Reiss_Nelson            Reiss Nelson_200641
#
#         Ainsley Maitland-Niles         Ainsley_Maitland-Niles  Ainsley Maitland-Niles_154043
#
#                  Danny Welbeck                  Danny_Welbeck            Danny Welbeck_50175
#
#            Alexandre Lacazette            Alexandre_Lacazette      Alexandre Lacazette_59966
#
#      Pierre-Emerick Aubameyang      Pierre-Emerick_Aubameyang Pierre-Emerick Aubameyang_54694
#
#                 Lucas Torreira                 Lucas_Torreira          Lucas Torreira_198849
#
#               Matteo Guendouzi               Matteo_Guendouzi        Matteo Guendouzi_242166
#
#                  Asmir Begovic                  Asmir_Begovic            Asmir Begovic_40349
#
#                    Artur Boruc                    Artur_Boruc              Artur Boruc_18726
#
#                  Simon Francis                  Simon_Francis            Simon Francis_15149
#
#                     Steve Cook                     Steve_Cook               Steve Cook_56917
#
#                Charlie Daniels                Charlie_Daniels          Charlie Daniels_41320
#
#                     Adam Smith                     Adam_Smith               Adam Smith_54469
#
#                   Tyrone Mings                   Tyrone_Mings            Tyrone Mings_149484
#
#                     Nathan Aké                     Nathan_Aké              Nathan Aké_126184
#
#                   Jack Simpson                   Jack_Simpson            Jack Simpson_222434
#
#                      Marc Pugh                      Marc_Pugh                Marc Pugh_20037
#
#                  Andrew Surman                  Andrew_Surman            Andrew Surman_15237
#
#               Junior Stanislas               Junior_Stanislas         Junior Stanislas_56872
#
#                    Dan Gosling                    Dan_Gosling              Dan Gosling_40387
#
#                     Jordon Ibe                     Jordon_Ibe              Jordon Ibe_103912
#
#                     Lewis Cook                     Lewis_Cook              Lewis Cook_155408
#
#                    Ryan Fraser                    Ryan_Fraser              Ryan Fraser_90105
#
#                Emerson Hyndman                Emerson_Hyndman         Emerson Hyndman_122342
#
#                   David Brooks                   David_Brooks            David Brooks_111317
#
#                  Callum Wilson                  Callum_Wilson            Callum Wilson_75115
#
#                    Lys Mousset                    Lys_Mousset             Lys Mousset_178304
#
#                    Joshua King                    Joshua_King              Joshua King_78007
#
#                  Jermain Defoe                  Jermain_Defoe             Jermain Defoe_7958
#
#                     Diego Rico                     Diego_Rico              Diego Rico_171129
#
#                Jefferson Lerma                Jefferson_Lerma         Jefferson Lerma_152551
#
#                    Mathew Ryan                    Mathew_Ryan             Mathew Ryan_131897
#
#                     Lewis Dunk                     Lewis_Dunk               Lewis Dunk_83299
#
#                    Shane Duffy                    Shane_Duffy              Shane Duffy_61933
#
#              Bruno Saltor Grau              Bruno_Saltor Grau        Bruno Saltor Grau_11352
#
#                    Gaëtan Bong                    Gaëtan_Bong              Gaëtan Bong_42748
#
#                 Markus Suttner                 Markus_Suttner           Markus Suttner_43808
#
#             Ezequiel Schelotto             Ezequiel_Schelotto       Ezequiel Schelotto_74375
#
#                   Leon Balogun                   Leon_Balogun             Leon Balogun_52484
#
#              Anthony Knockaert              Anthony_Knockaert        Anthony Knockaert_83543
#
#                  Dale Stephens                  Dale_Stephens            Dale Stephens_40845
#
#                    Beram Kayal                    Beram_Kayal              Beram Kayal_38490
#
#                  Solomon March                  Solomon_March           Solomon March_109345
#
#                    Pascal Groß                    Pascal_Groß              Pascal Groß_60307
#
#                   Davy Pröpper                   Davy_Pröpper             Davy Pröpper_66242
#
#  José Heriberto Izquierdo Mena  José Heriberto_Izquierdo Mena José Heriberto Izquierdo Mena_167473
#
#                   Glenn Murray                   Glenn_Murray             Glenn Murray_20529
#
#                    Tomer Hemed                    Tomer_Hemed              Tomer Hemed_38499
#
#                    Sam Baldock                    Sam_Baldock              Sam Baldock_28462
#
#                 Jürgen Locadia                 Jürgen_Locadia          Jürgen Locadia_106757
#
#                  Florin Andone                  Florin_Andone            Florin Andone_93284
#
#                   David Button                   David_Button             David Button_50093
#
#                   Jason Steele                   Jason_Steele             Jason Steele_49262
#
# Bernardo Fernandes da Silva Junior Bernardo_Fernandes da Silva Junior Bernardo Fernandes da Silva Junior_209362
#
#                  Yves Bissouma                  Yves_Bissouma           Yves Bissouma_227127
#
#            Alireza Jahanbakhsh            Alireza_Jahanbakhsh     Alireza Jahanbakhsh_165210
#
#                 Martín Montoya                 Martín_Montoya           Martín Montoya_86153
#
#                     Tom Heaton                     Tom_Heaton               Tom Heaton_21205
#
#                      Nick Pope                      Nick_Pope                Nick Pope_98747
#
#                 Matthew Lowton                 Matthew_Lowton           Matthew Lowton_68983
#
#                        Ben Mee                        Ben_Mee                  Ben Mee_51927
#
#                   Stephen Ward                   Stephen_Ward             Stephen Ward_40616
#
#                James Tarkowski                James_Tarkowski          James Tarkowski_17761
#
#                     Kevin Long                     Kevin_Long               Kevin Long_41674
#
#                 Charlie Taylor                 Charlie_Taylor          Charlie Taylor_103914
#
#                  Phil Bardsley                  Phil_Bardsley            Phil Bardsley_17997
#
#        Johann Berg Gudmundsson        Johann Berg_Gudmundsson  Johann Berg Gudmundsson_60586
#
#                  Steven Defour                  Steven_Defour            Steven Defour_39847
#
#                  Jeff Hendrick                  Jeff_Hendrick            Jeff Hendrick_83314
#
#                   Robbie Brady                   Robbie_Brady             Robbie Brady_90517
#
#                Ashley Westwood                Ashley_Westwood          Ashley Westwood_60551
#
#               Jonathan Walters               Jonathan_Walters         Jonathan Walters_12813
#
#                      Jack Cork                      Jack_Cork                Jack Cork_40145
#
#                   Aaron Lennon                   Aaron_Lennon             Aaron Lennon_17349
#
#                      Sam Vokes                      Sam_Vokes                Sam Vokes_40399
#
#                  Ashley Barnes                  Ashley_Barnes            Ashley Barnes_44699
#
#                    Nahki Wells                    Nahki_Wells              Nahki Wells_92383
#
#                     Chris Wood                     Chris_Wood               Chris Wood_60689
#
#              Anders Lindegaard              Anders_Lindegaard        Anders Lindegaard_39725
#
#                       Joe Hart                       Joe_Hart                 Joe Hart_15749
#
#                     Ben Gibson                     Ben_Gibson               Ben Gibson_83312
#
#                    Matej Vydra                    Matej_Vydra              Matej Vydra_81183
#
#                  Dwight McNeil                  Dwight_McNeil           Dwight McNeil_433154
#
#                    Harry Arter                    Harry_Arter              Harry Arter_48615
#
#                 Neil Etheridge                 Neil_Etheridge           Neil Etheridge_88734
#
#                  Alex Smithies                  Alex_Smithies            Alex Smithies_45220
#
#                  Sean Morrison                  Sean_Morrison            Sean Morrison_49982
#
#                      Sol Bamba                      Sol_Bamba                Sol Bamba_19523
#
#             Bruno Ecuele Manga             Bruno_Ecuele Manga       Bruno Ecuele Manga_49382
#
#               Matthew Connolly               Matthew_Connolly         Matthew Connolly_27698
#
#                    Joe Bennett                    Joe_Bennett              Joe Bennett_56981
#
#                    Lee Peltier                    Lee_Peltier              Lee Peltier_38716
#
#     Ashley Darel Jazz Richards     Ashley Darel Jazz_Richards Ashley Darel Jazz Richards_73459
#
#                   Greg Halford                   Greg_Halford             Greg Halford_14927
#
#                      Joe Ralls                      Joe_Ralls               Joe Ralls_104073
#
#           David Junior Hoilett           David Junior_Hoilett     David Junior Hoilett_49806
#
#         Nathaniel Mendez-Laing         Nathaniel_Mendez-Laing   Nathaniel Mendez-Laing_76360
#
#                Callum Paterson                Callum_Paterson         Callum Paterson_122797
#
#                Aron Gunnarsson                Aron_Gunnarsson          Aron Gunnarsson_49845
#
#             Anthony Pilkington             Anthony_Pilkington       Anthony Pilkington_40451
#
#                    Loïc Damour                    Loïc_Damour              Loïc Damour_54527
#
#                     Danny Ward                     Danny_Ward               Danny Ward_75826
#
#                    Josh Murphy                    Josh_Murphy             Josh Murphy_114245
#
#                 Kenneth Zohore                 Kenneth_Zohore           Kenneth Zohore_82078
#
#                     Omar Bogle                     Omar_Bogle              Omar Bogle_114054
#
#                    Gary Madine                    Gary_Madine              Gary Madine_45196
#
#                     Bobby Reid                     Bobby_Reid               Bobby Reid_96994
#
#               Greg Cunninghamm               Greg_Cunninghamm         Greg Cunninghamm_80792
#
#                Víctor Camarasa                Víctor_Camarasa         Víctor Camarasa_175946
#
#                  Kadeem Harris                  Kadeem_Harris            Kadeem Harris_78911
#
#                   Brian Murphy                   Brian_Murphy             Brian Murphy_10589
#
#               Thibaut Courtois               Thibaut_Courtois         Thibaut Courtois_60772
#
#                Willy Caballero                Willy_Caballero          Willy Caballero_20310
#
#              César Azpilicueta              César_Azpilicueta        César Azpilicueta_41328
#
#                    Gary Cahill                    Gary_Cahill              Gary Cahill_19419
#
#                  Marcos Alonso                  Marcos_Alonso            Marcos Alonso_82263
#
#
#                 Rachid Ghezzal                 Rachid_Ghezzal          Rachid Ghezzal_115858
#
#                 Filip Benkovic                 Filip_Benkovic          Filip Benkovic_213405
#
#                 Caglar Söyüncü                 Caglar_Söyüncü          Caglar Söyüncü_218031
#
#                 Nampalys Mendy                 Nampalys_Mendy           Nampalys Mendy_86881
#
#                 Simon Mignolet                 Simon_Mignolet           Simon Mignolet_66797
#
#                   Loris Karius                   Loris_Karius            Loris Karius_104542
#
#                   Dejan Lovren                   Dejan_Lovren             Dejan Lovren_38454
#
#                 Alberto Moreno                 Alberto_Moreno          Alberto Moreno_100059
#
#                Nathaniel Clyne                Nathaniel_Clyne          Nathaniel Clyne_57328
#
#                   Joseph Gomez                   Joseph_Gomez            Joseph Gomez_171287
#
#                     Joel Matip                     Joel_Matip               Joel Matip_60914
#
#                  Ragnar Klavan                  Ragnar_Klavan            Ragnar Klavan_33871
#
#         Trent Alexander-Arnold         Trent_Alexander-Arnold  Trent Alexander-Arnold_169187
#
#                Virgil van Dijk                Virgil_van Dijk          Virgil van Dijk_97032
#
#               Andrew Robertson               Andrew_Robertson        Andrew Robertson_122798
#
#        Alex Oxlade-Chamberlain        Alex_Oxlade-Chamberlain  Alex Oxlade-Chamberlain_81880
#
#               Jordan Henderson               Jordan_Henderson         Jordan Henderson_56979
#
#                   Adam Lallana                   Adam_Lallana             Adam Lallana_39155
#
#                     Sadio Mané                     Sadio_Mané              Sadio Mané_110979
#
#            Georginio Wijnaldum            Georginio_Wijnaldum      Georginio Wijnaldum_41733
#
#                  Mohamed Salah                  Mohamed_Salah           Mohamed Salah_118748
#
#                   James Milner                   James_Milner             James Milner_15157
#
#         Fabio Henrique Tavares         Fabio Henrique_Tavares  Fabio Henrique Tavares_116643
#
#                     Naby Keita                     Naby_Keita              Naby Keita_175592
#
#                Roberto Firmino                Roberto_Firmino          Roberto Firmino_92217
#
#                Dominic Solanke                Dominic_Solanke         Dominic Solanke_154566
#
#                Xherdan Shaqiri                Xherdan_Shaqiri          Xherdan Shaqiri_68312
#
#          Alisson Ramses Becker          Alisson_Ramses Becker   Alisson Ramses Becker_116535
#
#               Daniel Sturridge               Daniel_Sturridge         Daniel Sturridge_40755
#
#                   Riyad Mahrez                   Riyad_Mahrez            Riyad Mahrez_103025
#
#      Ederson Santana de Moraes      Ederson_Santana de Moraes Ederson Santana de Moraes_121160
#
#                  Claudio Bravo                  Claudio_Bravo            Claudio Bravo_33148
#
#                    John Stones                    John_Stones              John Stones_97299
#
#                Vincent Kompany                Vincent_Kompany          Vincent Kompany_17476
#
#               Nicolás Otamendi               Nicolás_Otamendi         Nicolás Otamendi_57410
#
#                    Kyle Walker                    Kyle_Walker              Kyle Walker_58621
#
#           Danilo Luiz da Silva           Danilo Luiz_da Silva    Danilo Luiz da Silva_100180
#
#                 Benjamin Mendy                 Benjamin_Mendy          Benjamin Mendy_102826
#
#                Aymeric Laporte                Aymeric_Laporte         Aymeric Laporte_146941
#
#                   Fabian Delph                   Fabian_Delph             Fabian Delph_41823
#
#
#                 Sofiane Boufal                 Sofiane_Boufal          Sofiane Boufal_128198
#
#                    Joshua Sims                    Joshua_Sims             Joshua Sims_153379
#
#                 Nathan Redmond                 Nathan_Redmond           Nathan Redmond_83283
#
#                   Mario Lemina                   Mario_Lemina            Mario Lemina_151086
#
#               Stuart Armstrong               Stuart_Armstrong         Stuart Armstrong_91047
#
#            Mohamed Elyounoussi            Mohamed_Elyounoussi      Mohamed Elyounoussi_96787
#
#                     Shane Long                     Shane_Long               Shane Long_20452
#
#                 Charlie Austin                 Charlie_Austin           Charlie Austin_78356
#
#              Manolo Gabbiadini              Manolo_Gabbiadini        Manolo Gabbiadini_61548
#
#                 Guido Carrillo                 Guido_Carrillo           Guido Carrillo_98914
#
#                     Angus Gunn                     Angus_Gunn              Angus Gunn_107265
#
#             Jannik Vestergaard             Jannik_Vestergaard       Jannik Vestergaard_93100
#
#                   Matt Targett                   Matt_Targett            Matt Targett_169359
#
#                    Hugo Lloris                    Hugo_Lloris              Hugo Lloris_37915
#
#                    Michel Vorm                    Michel_Vorm              Michel Vorm_39215
#
#              Toby Alderweireld              Toby_Alderweireld        Toby Alderweireld_55605
#
#                     Danny Rose                     Danny_Rose               Danny Rose_38290
#
#                 Jan Vertonghen                 Jan_Vertonghen           Jan Vertonghen_39194
#
#                     Ben Davies                     Ben_Davies              Ben Davies_115556
#
#                Kieran Trippier                Kieran_Trippier          Kieran Trippier_77794
#
#             Kyle Walker-Peters             Kyle_Walker-Peters      Kyle Walker-Peters_158534
#
#               Davinson Sánchez               Davinson_Sánchez        Davinson Sánchez_173904
#
#                   Serge Aurier                   Serge_Aurier             Serge Aurier_80226
#
#                      Eric Dier                      Eric_Dier                Eric Dier_93264
#
#                  Mousa Dembélé                  Mousa_Dembélé            Mousa Dembélé_39104
#
#                    Erik Lamela                    Erik_Lamela              Erik Lamela_62974
#
#              Christian Eriksen              Christian_Eriksen        Christian Eriksen_80607
#
#                  Bamidele Alli                  Bamidele_Alli           Bamidele Alli_108823
#
#                 Victor Wanyama                 Victor_Wanyama           Victor Wanyama_54756
#
#                  Heung-Min Son                  Heung-Min_Son            Heung-Min Son_85971
#
#                    Harry Winks                    Harry_Winks             Harry Winks_157668
#
#                 Moussa Sissoko                 Moussa_Sissoko           Moussa Sissoko_45268
#
# Lucas Rodrigues Moura da Silva Lucas_Rodrigues Moura da Silva Lucas Rodrigues Moura da Silva_95715
#
#              Fernando Llorente              Fernando_Llorente        Fernando Llorente_19760
#
#                     Harry Kane                     Harry_Kane               Harry Kane_78830
#
#          Georges-Kévin Nkoudou          Georges-Kévin_Nkoudou   Georges-Kévin Nkoudou_168566
#
#                      Luke Amos                      Luke_Amos               Luke Amos_168764
#
#                Paulo Gazzaniga                Paulo_Gazzaniga         Paulo Gazzaniga_102884
#
#                 Heurelho Gomes                 Heurelho_Gomes           Heurelho Gomes_18656
#
#                Pontus Dahlberg                Pontus_Dahlberg         Pontus Dahlberg_206882
#
#                  Younes Kaboul                  Younes_Kaboul            Younes Kaboul_37742
#
#                 Craig Cathcart                 Craig_Cathcart           Craig Cathcart_41338
#
#                Sebastian Prödl                Sebastian_Prödl          Sebastian Prödl_41945
#
#                   José Holebas                   José_Holebas             José Holebas_40868
#
#                  Miguel Britos                  Miguel_Britos            Miguel Britos_52153
#
#             Christian Kabasele             Christian_Kabasele       Christian Kabasele_85624
#
#                  Daryl Janmaat                  Daryl_Janmaat            Daryl Janmaat_52940
#
#                Adrian Mariappa                Adrian_Mariappa          Adrian Mariappa_20145
#
#          Francisco Femenía Far          Francisco_Femenía Far    Francisco Femenía Far_54484
#
#               Marvin Zeegelaar               Marvin_Zeegelaar         Marvin Zeegelaar_66247
#
#                   Marc Navarro                   Marc_Navarro            Marc Navarro_220166
#
#                    Adam Masina                    Adam_Masina             Adam Masina_155651
#
#             Nathaniel Chalobah             Nathaniel_Chalobah       Nathaniel Chalobah_89085
#
#                  Tom Cleverley                  Tom_Cleverley            Tom Cleverley_43250
#
#                 Etienne Capoue                 Etienne_Capoue           Etienne Capoue_38439
#
#             Abdoulaye Doucouré             Abdoulaye_Doucouré      Abdoulaye Doucouré_121599
#
#                Roberto Pereyra                Roberto_Pereyra          Roberto Pereyra_61566
#
#                    Will Hughes                    Will_Hughes             Will Hughes_108413
#
#                Gerard Deulofeu                Gerard_Deulofeu          Gerard Deulofeu_94924
#
#                     Andre Gray                     Andre_Gray               Andre Gray_73426
#
#                    Troy Deeney                    Troy_Deeney              Troy Deeney_41725
#
#                  Stefano Okaka                  Stefano_Okaka            Stefano Okaka_20046
#
#                Jerome Sinclair                Jerome_Sinclair         Jerome Sinclair_133801
#
#                     Ben Foster                     Ben_Foster                Ben Foster_9089
#
#                       Ken Sema                       Ken_Sema                Ken Sema_157775
#
#                 Domingos Quina                 Domingos_Quina          Domingos Quina_216058
#
#            Isaac Success Ajayi            Isaac_Success Ajayi     Isaac Success Ajayi_173514
#
# Adrián San Miguel del Castillo Adrián_San Miguel del Castillo Adrián San Miguel del Castillo_60706
#
#               Lukasz Fabianski               Lukasz_Fabianski         Lukasz Fabianski_37096
#
#                   Winston Reid                   Winston_Reid             Winston Reid_48717
#
#                Aaron Cresswell                Aaron_Cresswell          Aaron Cresswell_55459
#
#                 Angelo Ogbonna                 Angelo_Ogbonna           Angelo Ogbonna_40669
#
#                      Sam Byram                      Sam_Byram               Sam Byram_113564
#
#                 Pablo Zabaleta                 Pablo_Zabaleta           Pablo Zabaleta_20658
#
#                    Declan Rice                    Declan_Rice             Declan Rice_204480
#
#                   Reece Oxford                   Reece_Oxford            Reece Oxford_173792
#
#                Ryan Fredericks                Ryan_Fredericks          Ryan Fredericks_81012
#
#                      Issa Diop                      Issa_Diop               Issa Diop_219924
#
#                 Arthur Masuaku                 Arthur_Masuaku          Arthur Masuaku_105717
#
#                     Mark Noble                     Mark_Noble               Mark Noble_18073
#
#                   Pedro Obiang                   Pedro_Obiang             Pedro Obiang_59779
#
#                 Manuel Lanzini                 Manuel_Lanzini           Manuel Lanzini_86934
#
#                Michail Antonio                Michail_Antonio          Michail Antonio_57531
#
