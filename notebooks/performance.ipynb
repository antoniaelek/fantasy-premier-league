# %%
# %config IPCompleter.greedy=True

import import_ipynb
from functions import get_raw_data

import glob
import os
import pandas
import sys
import requests
# Out:
# importing Jupyter notebook from functions.ipynb

# %%
import plotly.graph_objs as go
import plotly.offline

import chart_studio
import chart_studio.plotly as py
#chart_studio .tools.set_credentials_file(username='user', api_key='***')

# %% [markdown]
# # Functions

# %%
def to_pretty_print(input_str):
    return input_str.replace('_', ' ').capitalize()


def from_pretty_print(input_str):
    return input_str.replace(' ', '_').lower()

# %%
def get_aggregate_functions():
    return ['average', 'median', 'sum', 'count', 'min', 'max']


def get_features_for_aggregation():
    return ['assists', 'bonus', 'bps',
            'clean_sheets', 'cost', 'creativity',
            'goals_conceded', 'goals_scored', 'ict_index', 'influence',
            'minutes', 'own_goals',
            'penalties_missed', 'penalties_saved', 'red_cards', 'saves', 'selected',
            'threat', 'total_points', 'transfers_balance',
            'transfers_in', 'transfers_out', 'yellow_cards']


def get_aggregate_features():
    features = get_features_for_aggregation()
    aggregates = get_aggregate_functions()

    features_out = ['name_id', 'id', 'name']
    for feature in features:
        for aggregate in aggregates:
            features_out.append(aggregate + "_" + feature)

    return features_out


def get_detailed_aggregate_data(base_path, season):
    features_in = get_features_for_aggregation()
    features_out = get_aggregate_features()
    features_out.append('cost')

    df_out = pandas.DataFrame(columns=features_out)
    df_out.set_index('id')

    for file in glob.glob(base_path + 'data/' + season + '/players/*/gw.csv'):
        try:
            df_in = pandas.read_csv(file, encoding='latin_1')
            df_in['value'] = df_in['value']/10
            df_in.rename(columns={'value': 'cost'}, inplace=True)

            element_id = df_in['element'][0]
            name_id = file.replace('/', '\\').split('\\')[-2]
            name = name_id[:int(name_id.rfind("_"))]
            name = name.replace("_", " ")

            features_out_dict = {}
            for feature in features_in:
                features_out_dict["average_" + feature] = df_in[feature].mean()
                features_out_dict["median_" + feature] = df_in[feature].median()
                features_out_dict["sum_" + feature] = df_in[feature].sum()
                features_out_dict["count_" + feature] = df_in[feature].count()
                features_out_dict["min_" + feature] = df_in[feature].min()
                features_out_dict["max_" + feature] = df_in[feature].max()


            features_out_dict['cost'] = df_in['cost']    
            features_out_dict['name_id'] = name_id
            features_out_dict['id'] = element_id
            features_out_dict['name'] = name
            df_out.loc[name_id] = pandas.Series(features_out_dict)
        except:
            print(file)
    
    df_out = df_out.fillna(0)
    return df_out

# %%
def get_agg_features(features, aggregates):
    agg_features = []
    for feature in features:
        for agg in aggregates:
            agg_features.append(agg + '_' + feature)
    return agg_features


def get_trace(df, x_metrics, y_metrics, color):
    return go.Bar(
        x = df[x_metrics],        
        y = df[y_metrics],
        text = df['name'],        
        #mode = 'markers',        
        marker=dict(color=color),
        hovertemplate = "<b>%{text}</b><br><br>" +
            y_metrics+": %{y:.2f}</br>"+
#             x_metrics+": %{x}</br>"+
            "<extra></extra>")


def get_data(df, x_metrics, y_metrics, color):
    data = []
    for x in x_metrics:
        for y in y_metrics:
            data.append(get_trace(df, x, y, color))
    
    for el in data[1:]:
        el['visible'] = 'legendonly'
    
    return data


def get_layout(df, x_metrics, y_metrics, title, show_dropdown=True):  
    buttons=[]
    i = 0
    for x in x_metrics.keys():
        for y in y_metrics.keys():
            template = [False] * len(y_metrics)
            template[i] = True
            buttons.append(dict(label = y_metrics[y], method = 'update', args = [{'visible': template}]))        
            i+=1
        
    updatemenus = list([
        dict(active=0,
             bgcolor = 'rgba(255,255,255,100)',
             pad = {'r': 0, 't': 10},
             x = 0,
             y = 1.18,
             xanchor = 'left',
             buttons=buttons)])
    
    if show_dropdown==False:
        updatemenus=None
    
    layout = go.Layout(
        hovermode = 'closest',
        showlegend=False,
        updatemenus=updatemenus, 
        modebar={'bgcolor': 'rgba(0,0,0,0)'},
        paper_bgcolor='rgba(0,0,0,0)',
        plot_bgcolor='rgba(0,0,0,0)',
        xaxis=go.layout.XAxis(
            color='white',
            title=go.layout.xaxis.Title(
                text='',
                font=dict(
                    size=18
                )
            )
        ),
        yaxis=go.layout.YAxis(
            color='white',
            title=go.layout.yaxis.Title(
                text='',
                font=dict(
                    size=18
                )
            )
        )
    )
    return layout


def get_figure(df, x_metrics, y_metrics, title = '', color='rgba(101,255,71, 0.4)', show_dropdown=True):    
    data = get_data(df, x_metrics, y_metrics, color)
    layout = get_layout(df, x_metrics, y_metrics, title, show_dropdown)
    
    return go.Figure(data=data, layout=layout)


def generate_performance_plots(points_dict, df, position, aggregate="average"):
    if aggregate != "" and aggregate[-1] != "_":
        aggregate += "_"

    df = df.copy(deep=True)

    df['achievements'] = get_achievements(df, points_dict)
    df['errors'] = get_errors(df, points_dict)
    df['value'] = df['achievements'] - df['errors']
    df = df[(df['sum_minutes'] > 0)]# & (df['errors'] > 0) & (df['value'] > 0)]
    
    plot3 = get_figure(df, {'web_name':'Name'}, {'value':'Value'}, 'value', 'white', show_dropdown=True)
#     plotly.offline.iplot(plot3)
    chart_studio.plotly.plot(plot3, filename=(position+"value"))
    
    y1 = {'achievements':'Achievements'}
    for a in filter_achievements(points_dict).keys(): y1[aggregate + a]=to_pretty_print(aggregate + a)
    plot1 = get_figure(df, {'web_name':'Name'}, y1, 'achievements', 'white', show_dropdown=True)
#     plotly.offline.iplot(plot1)
    chart_studio.plotly.plot(plot1, filename=(position+"achievements"))

    y2 = {'errors':'Errors'}
    for e in filter_errors(points_dict).keys(): y2[aggregate + e]=to_pretty_print(aggregate + e)
    plot2 = get_figure(df, {'web_name':'Name'}, y2, 'errors', 'white', show_dropdown=True)
#     plotly.offline.iplot(plot2)
    chart_studio.plotly.plot(plot2, filename=(position+"errors"))

    return df

# %%
def filter_achievements(points_dict):
    return {k:v for (k,v) in points_dict.items() if  v > 0}


def filter_errors(points_dict):
    return {k:v for (k,v) in points_dict.items() if  v < 0}


def get_errors(df, points_dict, aggregate="average"):
    errors = pandas.Series()
    for e in filter_errors(points_dict):
        tmp = (df[aggregate + "_" + e]*(0-points_dict[e]))
        errors = errors.add(tmp, fill_value=0)
    return errors


def get_achievements(df, points_dict, aggregate="average"):
    achievements = pandas.Series()
    for e in filter_achievements(points_dict):
        tmp = (df[aggregate + '_' + e]*(points_dict[e]))
        achievements = achievements.add(tmp, fill_value=0)
    return achievements

# %%
points_metrics = ['goals_scored','assists','own_goals','clean_sheetes','goals_conceded',
                  'penalties_missed','penalties_saved','minutes','yellow_cards']

defensive_metrics = ['clean_sheets','saves','penalties_saved','recoveries','clearances_blocks_interceptions','tackles',
                     'goals_conceded','own_goals','penalties_conceded','errors_leading_to_goal','errors_leading_to_goal_attempt']

creativity_metrics=['assists','big_chances_created','big_chances_missed',
                    'attempted_passes','completed_passes','key_passes','dribbles','open_play_crosses']

attack_metrics=['goals_scored','winning_goals','penalties_missed','target_missed','tackled','offside']

general_metrics=['minutes','red_cards','yellow_cards','fouls',
               'bonus','bps','total_points','ea_index','ict_index','influence','creativity','threat']

other_metrics=['cost','selected','loaned_in','loaned_out','transfers_in','transfers_out','transfers_balance']

points = {'assists':3,
          'own_goals':-2,
          'penalties_missed':-2,
          'minutes':1/45,
          'yellow_cards':-1,
          'red_cards':-3}

# %% [markdown]
# # Main

# %%
URL = "https://fantasy.premierleague.com/api/bootstrap-static/"
DATA = requests.get(URL).json()
CURR_GW_OBJS = [x for x in DATA['events'] if x['is_current'] == True]
if len(CURR_GW_OBJS) == 0:
    CURR_GW_OBJS = DATA['events']
CURR_GW = CURR_GW_OBJS[-1]['id']
SEASON = '2019-20'
BASE_PATH = '../scraper/'

# %%
agg_data = get_detailed_aggregate_data(BASE_PATH, SEASON)
raw_data = get_raw_data(BASE_PATH, SEASON)
# Out:
# ../scraper/data/2019-20/players\Muhamed_Bešić_522\gw.csv

# %%
raw_data.drop(columns=['name'],inplace=True)
df = pandas.merge(agg_data, raw_data, on='id', how='outer')
df['minutes_points'] = df['minutes']/45
df["web_name_lower"] = df["web_name"].str.lower()
df.sort_values(by="web_name_lower", inplace=True)

# %%
goalkeepers = df[df.position == 'Goalkeeper']
defenders = df[df.position == 'Defender']
midfielders = df[df.position == 'Midfielder']
forwards = df[df.position == 'Forward']

# %%
game_metrics_gkp = points_metrics + general_metrics + defensive_metrics
game_metrics_gkp = set(game_metrics_gkp)
game_metrics_gkp = get_agg_features(game_metrics_gkp, ['sum','average'])

points_gkp = points.copy()
points_gkp['goals_scored']=6
points_gkp['saves']=0.5
points_gkp['penalties_saved'] = 5
points_gkp['clean_sheets']=4
points_gkp['goals_conceded']=-1

gkp_df = generate_performance_plots(points_gkp, goalkeepers, 'Goalkeeper')

# %%
goalkeepers = goalkeepers.copy(deep=True)
goalkeepers['achievements'] = get_achievements(goalkeepers, points_gkp)
goalkeepers['errors'] = get_errors(goalkeepers, points_gkp)
goalkeepers['value'] = goalkeepers['achievements'] - goalkeepers['errors']
goalkeepers[goalkeepers['web_name']=='Alisson']
# goalkeepers
# Out:
#                       name_id   id                   name  average_assists  \
# 27  Alisson_Ramses Becker_189  189  Alisson Ramses Becker              0.0
#
#     median_assists  sum_assists  count_assists  min_assists  max_assists  \
# 27             0.0          0.0            5.0          0.0          0.0
#
#     average_bonus  ...  value_form  value_season  web_name  yellow_cards  \
# 27            0.0  ...         0.0           0.2   Alisson             0
#
#       position  minutes_points  web_name_lower  achievements  errors     value
# 27  Goalkeeper        0.844444         alisson      0.368889     0.0  0.368889
#
# [1 rows x 200 columns]

# %%
game_metrics_def = points_metrics + general_metrics + defensive_metrics
game_metrics_def = set(game_metrics_def)
game_metrics_def = get_agg_features(game_metrics_def, ['sum','average'])

points_def = points.copy()
points_def['goals_scored']=6
points_def['clean_sheets']=4
points_def['goals_conceded']=-1

generate_performance_plots(points_def, defenders, 'Defender')
# Out:
#                                         name_id   id  \
# 369                      Maximillian_Aarons_274  274
# 11                                Adam_Smith_63   63
# 395                               Nathan_Aké_59   59
# 500                       Toby_Alderweireld_331  331
# 506                  Trent_Alexander-Arnold_182  182
# 338                           Marcos_Alonso_103  103
# 475                            Serge_Aurier_336  336
# 112                       César_Azpilicueta_105  105
# 171                         Fabián_Balbuena_382  382
# 188                          George_Baldock_294  294
# 100                            Chris_Basham_423  423
# 243                            Jan_Bednarek_307  307
# 458                            Ryan_Bennett_404  404
# 71        Bernardo_Fernandes da Silva Junior_39   39
# 459                           Ryan_Bertrand_305  305
# 525                              Willy_Boly_405  405
# 186                              Gaëtan_Bong_41   41
# 124                                Dan_Burn_475  475
# 466                               Sam_Byram_454  454
# 185                             Gary_Cahill_503  503
# 288               João Pedro Cavaco_Cancelo_518  518
# 109                          Craig_Cathcart_358  358
# 83                           Calum_Chambers_467  467
# 60                        Benjamin_Chilwell_161  161
# 29                      Andreas_Christensen_108  108
# 107                             Conor_Coady_403  403
# 472                          Seamus_Coleman_144  144
# 1                           Aaron_Cresswell_376  376
# 111                           Cédric_Soares_486  486
# 89                           Charlie_Daniels_60   60
# ..                                          ...  ...
# 223                             Jack_Stacey_446  446
# 224                           Jack_Stephens_308  308
# 489                               Steve_Cook_58   58
# 160                            Enda_Stevens_291  291
# 266                             John_Stones_207  207
# 134                        Davinson_Sánchez_333  333
# 536                          Çaglar_Söyüncü_164  164
# 238                          James_Tarkowski_84   84
# 398                              Neil_Taylor_24   24
# 175                           Fikayo_Tomori_529  529
# 55                            Axel_Tuanzebe_481  481
# 531                              Yan_Valery_306  306
# 254                    Jesús_Vallejo Lázaro_473  473
# 415                     Patrick_van Aanholt_123  123
# 516                         Virgil_van Dijk_183  183
# 244                          Jan_Vertonghen_330  330
# 242                      Jannik_Vestergaard_304  304
# 464  Rúben Gonçalo_Silva Nascimento Vinagre_406  406
# 311                             Kyle_Walker_203  203
# 310                      Kyle_Walker-Peters_337  337
# 5                         Aaron_Wan-Bissaka_122  122
# 258                               Joel_Ward_126  126
# 12                             Adam_Webster_493  493
# 255                           Jetro_Willems_498  498
# 372                            Maya_Yoshida_310  310
# 53                             Ashley_Young_224  224
# 411                          Pablo_Zabaleta_379  379
# 99                     Christoph_Zimmermann_275  275
# 5         10.000000       wan-bissaka      3.600000     1.2  2.400000
# 258       10.000000              ward      3.600000     1.4  2.200000
# 12         4.000000           webster      0.800000     1.0 -0.200000
# 255        4.800000           willems      2.160000     1.0  1.160000
# 372        4.288889           yoshida      1.657778     0.4  1.257778
# 53         5.244444             young      1.848889     0.6  1.248889
# 411        0.466667          zabaleta      0.093333     0.0  0.093333
# 99         0.777778        zimmermann      0.155556     0.2 -0.044444
# 403       10.000000         zinchenko      3.600000     1.2  2.400000
# 309        9.000000             zouma      1.800000     2.8 -1.000000
#
# [128 rows x 200 columns]

# %%
game_metrics_mid = points_metrics + general_metrics + creativity_metrics + attack_metrics
game_metrics_mid = set(game_metrics_mid)

game_metrics_mid = get_agg_features(game_metrics_mid, ['sum','average'])

points_mid = points.copy()
points_mid['goals_scored']=5
points_mid['clean_sheets']=1
points_mid['goals_conceded']=0

generate_performance_plots(points_mid, midfielders, 'Midfielder')
# Out:
#                                          name_id   id  \
# 342                          Marc_Albrighton_174  174
# 59                             Bamidele_Alli_344  344
# 380                           Miguel_Almirón_266  266
# 210                           Ibrahim_Amadou_507  507
# 37                André Filipe_Tavares Gomes_422  422
# 378                          Michail_Antonio_389  389
# 490                         Stuart_Armstrong_323  323
# 93                            Christian_Atsu_267  267
# 455                             Ross_Barkley_117  117
# 202                            Harvey_Barnes_172  172
# 72            Bernard_Anício Caldeira Duarte_152  152
# 70   Bernardo Mota_Veiga de Carvalho e Silva_218  218
# 422                           Philip_Billing_476  476
# 484                           Sofiane_Boufal_508  508
# 157                         Emiliano_Buendía_283  283
# 517                          Víctor_Camarasa_510  510
# 501                            Todd_Cantwell_287  287
# 166                           Etienne_Capoue_373  373
# 85                            Carlos_Sánchez_397  397
# 115                Daniel_Ceballos Fernández_469  469
# 394                       Nathaniel_Chalobah_374  374
# 25                   Alex_Oxlade-Chamberlain_193  193
# 493                             Tahith_Chong_249  249
# 197                          Hamza_Choudhury_180  180
# 502                            Tom_Cleverley_371  371
# 219                                Jack_Cork_102  102
# 133                              David_Silva_219  219
# 503                               Tom_Davies_154  154
# 296                              Keinan_Davis_34   34
# 302                          Kevin_De Bruyne_215  215
# ..                                           ...  ...
# 196                         Gylfi_Sigurdsson_151  151
# 389                           Moussa_Sissoko_349  349
# 406                             Oliver_Skipp_352  352
# 449                         Robert_Snodgrass_393  393
# 205                            Heung-Min_Son_342  342
# 113                             Dale_Stephens_57   57
# 433                          Raheem_Sterling_214  214
# 340                        Marco_Stiepermann_285  285
# 32                              Andrew_Surman_80   80
# 19                          Alexander_Tettey_289  289
# 534                          Youri_Tielemans_448  448
# 326                            Lucas_Torreira_19   19
# 36                           Andros_Townsend_135  135
# 7                               Adama_Traoré_417  417
# 314                         Leandro_Trossard_421  421
# 505                              Tom_Trybull_290  290
# 335             Mahmoud Ahmed_Ibrahim Hassan_465  465
# 345                            Mario_Vrancic_282  282
# 497                             Theo_Walcott_153  153
# 240                        James_Ward-Prowse_321  321
# 52                           Ashley_Westwood_101  101
# 326        2.688889        torreira      1.537778     0.0  1.537778
# 36         5.755556        townsend      1.351111     0.0  1.351111
# 7          4.533333          traoré      0.906667     0.0  0.906667
# 314        5.488889        trossard      2.097778     0.0  2.097778
# 505        7.222222         trybull      1.644444     0.0  1.644444
# 335        6.266667       trézéguet      1.453333     0.8  0.653333
# 345        0.333333         vrancic      0.066667     0.0  0.066667
# 497        1.066667         walcott      0.213333     0.0  0.213333
# 240       10.000000     ward-prowse      2.400000     0.2  2.200000
# 52        10.000000        westwood      2.200000     0.2  2.000000
# 189        9.355556       wijnaldum      2.271111     0.0  2.271111
# 524        3.222222         willian      0.644444     0.0  0.644444
# 279        5.844444         willock      1.368889     0.0  1.368889
# 225        2.222222        wilshere      0.444444     0.0  0.444444
# 201        8.088889           winks      1.817778     0.6  1.217778
# 194        8.000000           xhaka      1.800000     0.4  1.400000
# 35         4.400000      yarmolenko      2.280000     0.0  2.280000
# 523        8.555556            zaha      1.911111     0.2  1.711111
# 373        1.555556            özil      0.311111     0.0  0.311111
#
# [168 rows x 200 columns]

# %%
game_metrics_fwd = points_metrics + general_metrics + creativity_metrics + attack_metrics
game_metrics_fwd = set(game_metrics_fwd)
game_metrics_fwd = get_agg_features(game_metrics_fwd, ['sum', 'average'])

points_fwd = points.copy()
points_fwd['goals_scored'] = 4
points_fwd['clean_sheets'] = 0
points_fwd['goals_conceded'] = 0

generate_performance_plots(points_fwd, forwards, 'Forward')
# Out:
#                                      name_id   id  \
# 494                        Tammy_Abraham_460  460
# 92                             Che_Adams_437  437
# 476                        Sergio_Agüero_210  210
# 177                         Florin_Andone_46   46
# 428             Pierre-Emerick_Aubameyang_11   11
# 272                          Jordan_Ayew_468  468
# 51                          Ashley_Barnes_90   90
# 379                      Michy_Batshuayi_461  461
# 94                     Christian_Benteke_129  129
# 82                          Callum_Wilson_67   67
# 149                Dominic_Calvert-Lewin_147  147
# 245            Javier_Hernández Balcázar_386  386
# 0                         Aaron_Connolly_534  534
# 413                      Patrick_Cutrone_487  487
# 507                          Troy_Deeney_362  362
# 190                      Gerard_Deulofeu_363  363
# 281                          Josip_Drmic_434  434
# 446                      Roberto_Firmino_187  187
# 407                       Olivier_Giroud_110  110
# 33                            Andre_Gray_364  364
# 354                      Mason_Greenwood_234  234
# 492                     Sébastien_Haller_457  457
# 120                           Danny_Ings_313  313
# 183            Gabriel Fernando_de Jesus_211  211
# 436                         Raúl_Jiménez_409  409
# 256  Joelinton Cássio_Apolinário de Lira_466  466
# 145                           Diogo_Jota_410  410
# 198                           Harry_Kane_338  338
# 384                           Moise_Kean_496  496
# 280                           Joshua_King_68   68
# 269                       Jonathan_Kodjia_26   26
# 21                    Alexandre_Lacazette_12   12
# 292                        Jürgen_Locadia_45   45
# 479                           Shane_Long_315  315
# 184     Gabriel Teodoro_Martinelli Silva_504  504
# 397                          Neal_Maupay_502  502
# 404                      Oliver_McBurnie_501  501
# 132                     David_McGoldrick_303  303
# 333                           Lys_Mousset_70   70
# 123          0.0            5.0          0.0          0.0            0.0  ...
# 520          0.0            5.0          0.0          0.0            0.6  ...
# 106          0.0            5.0          0.0          0.0            0.0  ...
# 103          0.0            5.0          0.0          0.0            0.0  ...
#
#      value_form  value_season       web_name  yellow_cards  position  \
# 494         1.4           5.8        Abraham             2   Forward
# 92          0.3           1.7          Adams             0   Forward
# 476         1.0           3.8         Agüero             0   Forward
# 177        -0.1           1.0         Andone             0   Forward
# 428         0.8           3.5     Aubameyang             1   Forward
# 272         0.9           4.1           Ayew             1   Forward
# 51          0.6           4.3         Barnes             1   Forward
# 379         0.2           0.7      Batshuayi             0   Forward
# 94          0.2           1.2        Benteke             0   Forward
# 82          1.0           4.2  Callum Wilson             1   Forward
# 149         0.5           2.1  Calvert-Lewin             1   Forward
# 245         0.0           1.5     Chicharito             0   Forward
# 0           0.2           0.4       Connolly             0   Forward
# 413         0.3           1.6        Cutrone             0   Forward
# 507         0.0           0.6         Deeney             0   Forward
# 190         0.5           2.1       Deulofeu             0   Forward
# 281         0.1           0.6          Drmic             0   Forward
# 446         0.8           3.7        Firmino             0   Forward
# 407         0.1           0.6         Giroud             0   Forward
# 33          0.6           2.4           Gray             0   Forward
# 354         0.2           0.9      Greenwood             0   Forward
# 492         1.0           3.3         Haller             0   Forward
# 120         0.4           2.7           Ings             0   Forward
# 183         0.1           1.2          Jesus             0   Forward
# 436         0.6           2.7        Jiménez             1   Forward
# 256         0.7           2.5      Joelinton             2   Forward
# 145         0.3           1.4           Jota             0   Forward
# 198         0.4           2.5           Kane             0   Forward
# 384         0.3           1.3           Kean             0   Forward
# 280         0.7           3.5           King             0   Forward
# 269         0.0           0.2         Kodjia             0   Forward
# 21          0.2           1.5      Lacazette             1   Forward
# 292         0.1           0.6        Locadia             0   Forward
# 479         0.1           0.4           Long             0   Forward
# 184         0.0           0.2     Martinelli             0   Forward
# 397         0.7           3.2         Maupay             0   Forward
# 404         0.4           1.9       McBurnie             1   Forward
# 132         0.3           1.5     McGoldrick             0   Forward
# 333         0.1           0.4        Mousset             0   Forward
# 192         0.2           1.4         Murray             0   Forward
# 533         0.2           0.7           Muto             0   Forward
# 376         0.0           0.2        Obafemi             0   Forward
# 146         0.1           2.8          Origi             0   Forward
# 496         1.2           6.9          Pukki             0   Forward
# 341         0.5           3.5       Rashford             0   Forward
# 247         0.2           0.9      Rodriguez             0   Forward
# 75          0.0           1.2          Sharp             0   Forward
# 150         0.2           1.1        Solanke             0   Forward
# 142         0.1           0.4         Srbeny             0   Forward
# 214         0.1           0.4        Success             0   Forward
# 241         0.8           3.4          Vardy             0   Forward
# 357         0.2           0.7          Vydra             0   Forward
# 123         0.0           0.3        Welbeck             0   Forward
# 520         0.7           2.8         Wesley             0   Forward
# 106         0.0           0.4        Wickham             0   Forward
# 103         0.2           1.3           Wood             0   Forward
#
#      minutes_points  web_name_lower  achievements  errors     value
# 494        7.266667         abraham      7.053333     0.8  6.253333
# 92         8.200000           adams      1.640000     0.0  1.640000
# 476        7.911111          agüero      7.782222     0.0  7.782222
# 177        1.577778          andone      1.115556     0.6  0.515556
# 428       10.000000      aubameyang      6.600000     0.2  6.400000
# 272        6.511111            ayew      2.902222     0.2  2.702222
# 51         9.155556          barnes      5.031111     0.2  4.831111
# 379        0.444444       batshuayi      0.688889     0.0  0.688889
# 94         4.666667         benteke      0.933333     0.0  0.933333
# 82         9.488889   callum wilson      6.097778     0.2  5.897778
# 149        6.955556   calvert-lewin      2.191111     0.2  1.991111
# 245        2.355556      chicharito      1.271111     0.0  1.271111
# 0          0.666667        connolly      0.333333     0.0  0.333333
# 413        2.822222         cutrone      1.364444     0.0  1.364444
# 507        4.000000          deeney      0.800000     0.0  0.800000
# 190        6.533333        deulofeu      1.906667     0.0  1.906667
# 281        0.600000           drmic      0.120000     0.0  0.120000
# 446        8.822222         firmino      5.764444     0.0  5.764444
# 407        2.222222          giroud      0.444444     0.0  0.444444
# 33         6.777778            gray      2.155556     0.0  2.155556
# 354        1.044444       greenwood      0.208889     0.0  0.208889
# 492        8.000000          haller      4.000000     0.0  4.000000
# 120        5.911111            ings      2.582222     0.0  2.582222
# 183        2.777778           jesus      1.955556     0.0  1.955556
# 436        9.533333         jiménez      3.506667     0.2  3.306667
# 256        9.400000       joelinton      2.680000     0.4  2.280000
# 145        8.044444            jota      1.608889     0.0  1.608889
# 198        9.866667            kane      4.973333     0.0  4.973333
# 384        3.577778            kean      1.315556     0.0  1.315556
# 280        9.733333            king      3.946667     0.0  3.946667
# 269        0.355556          kodjia      0.071111     0.0  0.071111
# 21         3.222222       lacazette      2.244444     0.2  2.044444
# 292        1.888889         locadia      0.377778     0.0  0.377778
# 479        0.644444            long      0.128889     0.0  0.128889
# 184        0.133333      martinelli      0.026667     0.0  0.026667
# 397        6.022222          maupay      2.804444     0.0  2.804444
# 404        4.955556        mcburnie      1.791111     0.2  1.591111
# 132        7.111111      mcgoldrick      1.422222     0.0  1.422222
# 333        0.644444         mousset      0.128889     0.0  0.128889
# 192        5.644444          murray      1.128889     0.0  1.128889
# 533        1.244444            muto      0.248889     0.0  0.248889
# 376        0.533333         obafemi      0.106667     0.0  0.106667
# 146        2.777778           origi      1.955556     0.0  1.955556
# 496        9.822222           pukki      7.964444     0.0  7.964444
# 341        9.844444        rashford      4.968889     0.4  4.568889
# 247        1.955556       rodriguez      0.391111     0.0  0.391111
# 75         1.422222           sharp      1.084444     0.6  0.484444
# 150        3.377778         solanke      0.675556     0.0  0.675556
# 142        0.222222          srbeny      0.044444     0.0  0.044444
# 214        0.755556         success      0.151111     0.0  0.151111
# 241       10.000000           vardy      5.000000     0.0  5.000000
# 357        0.266667           vydra      0.653333     0.0  0.653333
# 123        0.866667         welbeck      0.173333     0.0  0.173333
# 520        9.488889          wesley      2.697778     0.0  2.697778
# 106        0.333333         wickham      0.066667     0.0  0.066667
# 103        8.777778            wood      1.755556     0.4  1.355556
#
# [56 rows x 200 columns]
