# %%
# %config IPCompleter.greedy=True

import import_ipynb
from functions import get_raw_data

import glob
import os
import pandas
import sys
import requests

# %%
import plotly.graph_objs as go
import plotly.offline

import chart_studio
import chart_studio.plotly as py
#chart_studio .tools.set_credentials_file(username='user', api_key='***')

# %% [markdown]
# # Functions

# %%
def to_pretty_print(input_str):
    return input_str.replace('_', ' ').capitalize()


def from_pretty_print(input_str):
    return input_str.replace(' ', '_').lower()

# %%
def get_aggregate_functions():
    return ['average', 'median', 'sum', 'count', 'min', 'max']


def get_features_for_aggregation():
    return ['assists', 'bonus', 'bps',
            'clean_sheets', 'cost', 'creativity',
            'goals_conceded', 'goals_scored', 'ict_index', 'influence',
            'minutes', 'own_goals',
            'penalties_missed', 'penalties_saved', 'red_cards', 'saves', 'selected',
            'threat', 'total_points', 'transfers_balance',
            'transfers_in', 'transfers_out', 'yellow_cards']


def get_aggregate_features():
    features = get_features_for_aggregation()
    aggregates = get_aggregate_functions()

    features_out = ['name_id', 'id', 'name']
    for feature in features:
        for aggregate in aggregates:
            features_out.append(aggregate + "_" + feature)

    return features_out


def get_detailed_aggregate_data(base_path, season):
    features_in = get_features_for_aggregation()
    features_out = get_aggregate_features()
    features_out.append('cost')

    df_out = pandas.DataFrame(columns=features_out)
    df_out.set_index('id')

    for file in glob.glob(base_path + 'data/' + season + '/players/*/gw.csv'):
        try:
            df_in = pandas.read_csv(file, encoding='latin_1')
            df_in['value'] = df_in['value']/10
            df_in.rename(columns={'value': 'cost'}, inplace=True)

            element_id = df_in['element'][0]
            name_id = file.replace('/', '\\').split('\\')[-2]
            name = name_id[:int(name_id.rfind("_"))]
            name = name.replace("_", " ")

            features_out_dict = {}
            for feature in features_in:
                features_out_dict["average_" + feature] = df_in[feature].mean()
                features_out_dict["median_" + feature] = df_in[feature].median()
                features_out_dict["sum_" + feature] = df_in[feature].sum()
                features_out_dict["count_" + feature] = df_in[feature].count()
                features_out_dict["min_" + feature] = df_in[feature].min()
                features_out_dict["max_" + feature] = df_in[feature].max()


            features_out_dict['cost'] = df_in['cost']    
            features_out_dict['name_id'] = name_id
            features_out_dict['id'] = element_id
            features_out_dict['name'] = name
            df_out.loc[name_id] = pandas.Series(features_out_dict)
        except:
            print(file)
    
    df_out = df_out.fillna(0)
    return df_out

# %%
def get_agg_features(features, aggregates):
    agg_features = []
    for feature in features:
        for agg in aggregates:
            agg_features.append(agg + '_' + feature)
    return agg_features


def get_trace(df, x_metrics, y_metrics, color):
    return go.Bar(
        x = df[x_metrics],        
        y = df[y_metrics],
        text = df['name'],        
        #mode = 'markers',        
        marker=dict(color=color),
        hovertemplate = "<b>%{text}</b><br><br>" +
            y_metrics+": %{y:.2f}</br>"+
#             x_metrics+": %{x}</br>"+
            "<extra></extra>")


def get_data(df, x_metrics, y_metrics, color):
    data = []
    for x in x_metrics:
        for y in y_metrics:
            data.append(get_trace(df, x, y, color))
    
    for el in data[1:]:
        el['visible'] = 'legendonly'
    
    return data


def get_layout(df, x_metrics, y_metrics, title, show_dropdown=True):  
    buttons=[]
    i = 0
    for x in x_metrics.keys():
        for y in y_metrics.keys():
            template = [False] * len(y_metrics)
            template[i] = True
            buttons.append(dict(label = y_metrics[y], method = 'update', args = [{'visible': template}]))        
            i+=1
        
    updatemenus = list([
        dict(active=0,
             bgcolor = 'rgba(255,255,255,100)',
             pad = {'r': 0, 't': 10},
             x = 0,
             y = 1.18,
             xanchor = 'left',
             buttons=buttons)])
    
    if show_dropdown==False:
        updatemenus=None
    
    layout = go.Layout(
        hovermode = 'closest',
        showlegend=False,
        updatemenus=updatemenus, 
        modebar={'bgcolor': 'rgba(0,0,0,0)'},
        paper_bgcolor='rgba(0,0,0,0)',
        plot_bgcolor='rgba(0,0,0,0)',
        xaxis=go.layout.XAxis(
            color='white',
            title=go.layout.xaxis.Title(
                text='',
                font=dict(
                    size=18
                )
            )
        ),
        yaxis=go.layout.YAxis(
            color='white',
            title=go.layout.yaxis.Title(
                text='',
                font=dict(
                    size=18
                )
            )
        )
    )
    return layout


def get_figure(df, x_metrics, y_metrics, title = '', color='rgba(101,255,71, 0.4)', show_dropdown=True):    
    data = get_data(df, x_metrics, y_metrics, color)
    layout = get_layout(df, x_metrics, y_metrics, title, show_dropdown)
    
    return go.Figure(data=data, layout=layout)


def generate_performance_plots(points_dict, df, position, aggregate="average"):
    if aggregate != "" and aggregate[-1] != "_":
        aggregate += "_"

    df = df.copy(deep=True)

    df['achievements'] = get_achievements(df, points_dict)
    df['errors'] = get_errors(df, points_dict)
    df['value'] = df['achievements'] - df['errors']
    df = df[(df['sum_minutes'] > 0)]# & (df['errors'] > 0) & (df['value'] > 0)]
    
    plot3 = get_figure(df, {'web_name':'Name'}, {'value':'Value'}, 'value', 'white', show_dropdown=True)
#     plotly.offline.iplot(plot3)
    chart_studio.plotly.plot(plot3, filename=(position+"value"))
    
    y1 = {'achievements':'Achievements'}
    for a in filter_achievements(points_dict).keys(): y1[aggregate + a]=to_pretty_print(aggregate + a)
    plot1 = get_figure(df, {'web_name':'Name'}, y1, 'achievements', 'white', show_dropdown=True)
#     plotly.offline.iplot(plot1)
    chart_studio.plotly.plot(plot1, filename=(position+"achievements"))

    y2 = {'errors':'Errors'}
    for e in filter_errors(points_dict).keys(): y2[aggregate + e]=to_pretty_print(aggregate + e)
    plot2 = get_figure(df, {'web_name':'Name'}, y2, 'errors', 'white', show_dropdown=True)
#     plotly.offline.iplot(plot2)
    chart_studio.plotly.plot(plot2, filename=(position+"errors"))

    return df

# %%
def filter_achievements(points_dict):
    return {k:v for (k,v) in points_dict.items() if  v > 0}


def filter_errors(points_dict):
    return {k:v for (k,v) in points_dict.items() if  v < 0}


def get_errors(df, points_dict, aggregate="average"):
    errors = pandas.Series()
    for e in filter_errors(points_dict):
        tmp = (df[aggregate + "_" + e]*(0-points_dict[e]))
        errors = errors.add(tmp, fill_value=0)
    return errors


def get_achievements(df, points_dict, aggregate="average"):
    achievements = pandas.Series()
    for e in filter_achievements(points_dict):
        tmp = (df[aggregate + '_' + e]*(points_dict[e]))
        achievements = achievements.add(tmp, fill_value=0)
    return achievements

# %%
points_metrics = ['goals_scored','assists','own_goals','clean_sheetes','goals_conceded',
                  'penalties_missed','penalties_saved','minutes','yellow_cards']

defensive_metrics = ['clean_sheets','saves','penalties_saved','recoveries','clearances_blocks_interceptions','tackles',
                     'goals_conceded','own_goals','penalties_conceded','errors_leading_to_goal','errors_leading_to_goal_attempt']

creativity_metrics=['assists','big_chances_created','big_chances_missed',
                    'attempted_passes','completed_passes','key_passes','dribbles','open_play_crosses']

attack_metrics=['goals_scored','winning_goals','penalties_missed','target_missed','tackled','offside']

general_metrics=['minutes','red_cards','yellow_cards','fouls',
               'bonus','bps','total_points','ea_index','ict_index','influence','creativity','threat']

other_metrics=['cost','selected','loaned_in','loaned_out','transfers_in','transfers_out','transfers_balance']

points = {'assists':3,
          'own_goals':-2,
          'penalties_missed':-2,
          'minutes':1/45,
          'yellow_cards':-1,
          'red_cards':-3}

# %% [markdown]
# # Main

# %%
URL = "https://fantasy.premierleague.com/api/bootstrap-static/"
DATA = requests.get(URL).json()
CURR_GW_OBJS = [x for x in DATA['events'] if x['is_current'] == True]
if len(CURR_GW_OBJS) == 0:
    CURR_GW_OBJS = DATA['events']
CURR_GW = CURR_GW_OBJS[-1]['id']
SEASON = '2019-20'
BASE_PATH = '../scraper/'

# %%
agg_data = get_detailed_aggregate_data(BASE_PATH, SEASON)
raw_data = get_raw_data(BASE_PATH, SEASON)
# Out:
# ../scraper/data/2019-20/players\Muhamed_Bešić_522\gw.csv

# %%
raw_data.drop(columns=['name'],inplace=True)
df = pandas.merge(agg_data, raw_data, on='id', how='outer')
df['minutes_points'] = df['minutes']/45
df["web_name_lower"] = df["web_name"].str.lower()
df.sort_values(by="web_name_lower", inplace=True)

# %%
goalkeepers = df[df.position == 'Goalkeeper']
defenders = df[df.position == 'Defender']
midfielders = df[df.position == 'Midfielder']
forwards = df[df.position == 'Forward']

# %%
goalkeepers = goalkeepers.copy(deep=True)
goalkeepers['achievements'] = get_achievements(goalkeepers, points_gkp)
goalkeepers['errors'] = get_errors(goalkeepers, points_gkp)
goalkeepers['value'] = goalkeepers['achievements'] - goalkeepers['errors']
goalkeepers[goalkeepers['web_name']=='Alisson']
# goalkeepers
# Out:
#                       name_id   id                   name  average_assists  \
# 25  Alisson_Ramses Becker_189  189  Alisson Ramses Becker              0.0
#
#     median_assists  sum_assists  count_assists  min_assists  max_assists  \
# 25             0.0          0.0            3.0          0.0          0.0
#
#     average_bonus  ...  value_form  value_season  web_name  yellow_cards  \
# 25            0.0  ...         0.1           0.2   Alisson             0
#
#       position  minutes_points  web_name_lower  achievements  errors     value
# 25  Goalkeeper        0.844444         alisson      0.614815     0.0  0.614815
#
# [1 rows x 200 columns]

# %%
game_metrics_gkp = points_metrics + general_metrics + defensive_metrics
game_metrics_gkp = set(game_metrics_gkp)
game_metrics_gkp = get_agg_features(game_metrics_gkp, ['sum','average'])

points_gkp = points.copy()
points_gkp['goals_scored']=6
points_gkp['saves']=0.5
points_gkp['penalties_saved'] = 5
points_gkp['clean_sheets']=4
points_gkp['goals_conceded']=-1

gkp_df = generate_performance_plots(points_gkp, goalkeepers, 'Goalkeeper')

# %%
game_metrics_def = points_metrics + general_metrics + defensive_metrics
game_metrics_def = set(game_metrics_def)
game_metrics_def = get_agg_features(game_metrics_def, ['sum','average'])

points_def = points.copy()
points_def['goals_scored']=6
points_def['clean_sheets']=4
points_def['goals_conceded']=-1

generate_performance_plots(points_def, defenders, 'Defender')
# Out:
#                                    name_id   id  \
# 361                 Maximillian_Aarons_274  274
# 9                            Adam_Smith_63   63
# 387                          Nathan_Aké_59   59
# 491                  Toby_Alderweireld_331  331
# 497             Trent_Alexander-Arnold_182  182
# 331                      Marcos_Alonso_103  103
# 108                  César_Azpilicueta_105  105
# 165                    Fabián_Balbuena_382  382
# 182                     George_Baldock_294  294
# 96                        Chris_Basham_423  423
# 236                       Jan_Bednarek_307  307
# 450                       Ryan_Bennett_404  404
# 69   Bernardo_Fernandes da Silva Junior_39   39
# 451                      Ryan_Bertrand_305  305
# 515                         Willy_Boly_405  405
# 119                           Dan_Burn_475  475
# 458                          Sam_Byram_454  454
# 179                        Gary_Cahill_503  503
# 281          João Pedro Cavaco_Cancelo_518  518
# 105                     Craig_Cathcart_358  358
# 79                      Calum_Chambers_467  467
# 58                   Benjamin_Chilwell_161  161
# 27                 Andreas_Christensen_108  108
# 103                        Conor_Coady_403  403
# 464                     Seamus_Coleman_144  144
# 0                      Aaron_Cresswell_376  376
# 85                      Charlie_Daniels_60   60
# 461                         Scott_Dann_127  127
# 294                        Kevin_Danso_532  532
# 126         David_Luiz Moreira Marinho_106  106
# ..                                     ...  ...
# 158                       Erik_Pieters_447  447
# 138                          Diego_Rico_65   65
# 359                       Matt_Ritchie_251  251
# 29                    Andrew_Robertson_181  181
# 116                         Danny_Rose_332  332
# 445                       Romain_Saïss_407  407
# 163                       Fabian_Schär_252  252
# 325                          Luke_Shaw_226  226
# 477            Sokratis_Papastathopoulos_5    5
# 218                      Jack_Stephens_308  308
# 480                          Steve_Cook_58   58
# 154                       Enda_Stevens_291  291
# 259                        John_Stones_207  207
# 129                   Davinson_Sánchez_333  333
# 526                     Çaglar_Söyüncü_164  164
# 231                     James_Tarkowski_84   84
# 390                         Neil_Taylor_24   24
# 521                         Yan_Valery_306  306
# 407                Patrick_van Aanholt_123  123
# 506                    Virgil_van Dijk_183  183
# 235                 Jannik_Vestergaard_304  304
# 304                        Kyle_Walker_203  203
# 303                 Kyle_Walker-Peters_337  337
# 4                    Aaron_Wan-Bissaka_122  122
# 251                          Joel_Ward_126  126
# 248                      Jetro_Willems_498  498
# 364                       Maya_Yoshida_310  310
# 51                        Ashley_Young_224  224
# 395                Oleksandr_Zinchenko_206  206
# 302                         Kurt_Zouma_459  459
#
#                                    name  average_assists  median_assists  \
# 361                  Maximillian Aarons         0.000000             0.0
# 9                            Adam Smith         0.000000             0.0
# 387                          Nathan Aké         0.000000             0.0
# 491                   Toby Alderweireld         0.000000             0.0
# 497              Trent Alexander-Arnold         0.666667             1.0
# 331                       Marcos Alonso         0.000000             0.0
# 108                   César Azpilicueta         0.333333             0.0
# 165                     Fabián Balbuena         0.000000             0.0
# 182                      George Baldock         0.333333             0.0
# 96                         Chris Basham         0.000000             0.0
# 236                        Jan Bednarek         0.000000             0.0
# 450                        Ryan Bennett         0.000000             0.0
# 69   Bernardo Fernandes da Silva Junior         0.000000             0.0
# 451                       Ryan Bertrand         0.000000             0.0
# 515                          Willy Boly         0.000000             0.0
# 119                            Dan Burn         0.000000             0.0
# 458                           Sam Byram         0.000000             0.0
# 179                         Gary Cahill         0.000000             0.0
# 281           João Pedro Cavaco Cancelo         0.000000             0.0
# 105                      Craig Cathcart         0.000000             0.0
# 79                       Calum Chambers         0.000000             0.0
# 58                    Benjamin Chilwell         0.000000             0.0
# 27                  Andreas Christensen         0.000000             0.0
# 103                         Conor Coady         0.000000             0.0
# 464                      Seamus Coleman         0.000000             0.0
# 0                       Aaron Cresswell         0.000000             0.0
# 85                      Charlie Daniels         0.000000             0.0
# 461                          Scott Dann         0.000000             0.0
# 294                         Kevin Danso         0.000000             0.0
# 126          David Luiz Moreira Marinho         0.000000             0.0
# ..                                  ...              ...             ...
# 158                        Erik Pieters         0.666667             0.0
# 138                          Diego Rico         0.000000             0.0
# 359                        Matt Ritchie         0.000000             0.0
# 29                     Andrew Robertson         0.000000             0.0
# 116                          Danny Rose         0.000000             0.0
# 445                        Romain Saïss         0.000000             0.0
# 163                        Fabian Schär         0.000000             0.0
# 325                           Luke Shaw         0.000000             0.0
# 477           Sokratis Papastathopoulos         0.000000             0.0
# 218                       Jack Stephens         0.000000             0.0
# 480                          Steve Cook         0.000000             0.0
# 154                        Enda Stevens         0.000000             0.0
# 259                         John Stones         0.000000             0.0
# 129                    Davinson Sánchez         0.000000             0.0
# 526                      Çaglar Söyüncü         0.333333             0.0
# 231                     James Tarkowski         0.000000             0.0
# 390                         Neil Taylor         0.000000             0.0
# 521                          Yan Valery         0.000000             0.0
# 407                 Patrick van Aanholt         0.000000             0.0
# 506                     Virgil van Dijk         0.000000             0.0
# 235                  Jannik Vestergaard         0.000000             0.0
# 304                         Kyle Walker         0.333333             0.0
# 303                  Kyle Walker-Peters         0.000000             0.0
# 4                     Aaron Wan-Bissaka         0.000000             0.0
# 251                           Joel Ward         0.000000             0.0
# 248                       Jetro Willems         0.000000             0.0
# 364                        Maya Yoshida         0.000000             0.0
# 51                         Ashley Young         0.000000             0.0
# 395                 Oleksandr Zinchenko         0.000000             0.0
# 302                          Kurt Zouma         0.000000             0.0
#
#      sum_assists  count_assists  min_assists  max_assists  average_bonus  ...  \
# 361          0.0            3.0          0.0          0.0       0.000000  ...
# 9            0.0            3.0          0.0          0.0       0.000000  ...
# 387          0.0            3.0          0.0          0.0       0.000000  ...
# 491          0.0            3.0          0.0          0.0       0.000000  ...
# 497          2.0            3.0          0.0          1.0       0.000000  ...
# 331          0.0            3.0          0.0          0.0       0.000000  ...
# 108          1.0            3.0          0.0          1.0       0.000000  ...
# 165          0.0            3.0          0.0          0.0       0.000000  ...
# 182          1.0            3.0          0.0          1.0       1.000000  ...
# 96           0.0            3.0          0.0          0.0       0.000000  ...
# 236          0.0            3.0          0.0          0.0       0.333333  ...
# 450          0.0            3.0          0.0          0.0       0.000000  ...
# 69           0.0            3.0          0.0          0.0       0.000000  ...
# 451          0.0            3.0          0.0          0.0       0.000000  ...
# 515          0.0            3.0          0.0          0.0       1.666667  ...
# 119          0.0            3.0          0.0          0.0       0.000000  ...
# 458          0.0            3.0          0.0          0.0       0.000000  ...
# 179          0.0            3.0          0.0          0.0       0.000000  ...
# 281          0.0            3.0          0.0          0.0       0.000000  ...
# 105          0.0            3.0          0.0          0.0       0.000000  ...
# 79           0.0            3.0          0.0          0.0       0.000000  ...
# 58           0.0            3.0          0.0          0.0       0.000000  ...
# 27           0.0            3.0          0.0          0.0       0.000000  ...
# 103          0.0            3.0          0.0          0.0       0.000000  ...
# 464          0.0            3.0          0.0          0.0       0.000000  ...
# 0            0.0            3.0          0.0          0.0       0.000000  ...
# 85           0.0            3.0          0.0          0.0       0.000000  ...
# 461          0.0            3.0          0.0          0.0       0.000000  ...
# 294          0.0            2.0          0.0          0.0       0.000000  ...
# 126          0.0            3.0          0.0          0.0       0.000000  ...
# ..           ...            ...          ...          ...            ...  ...
# 158          2.0            3.0          0.0          2.0       0.666667  ...
# 138          0.0            3.0          0.0          0.0       0.000000  ...
# 359          0.0            3.0          0.0          0.0       0.000000  ...
# 29           0.0            3.0          0.0          0.0       0.000000  ...
# 116          0.0            3.0          0.0          0.0       0.000000  ...
# 445          0.0            3.0          0.0          0.0       0.000000  ...
# 163          0.0            3.0          0.0          0.0       0.666667  ...
# 325          0.0            3.0          0.0          0.0       0.000000  ...
# 477          0.0            3.0          0.0          0.0       0.666667  ...
# 218          0.0            3.0          0.0          0.0       0.000000  ...
# 480          0.0            3.0          0.0          0.0       0.000000  ...
# 154          0.0            3.0          0.0          0.0       0.333333  ...
# 259          0.0            3.0          0.0          0.0       0.000000  ...
# 129          0.0            3.0          0.0          0.0       0.000000  ...
# 526          1.0            3.0          0.0          1.0       0.000000  ...
# 231          0.0            3.0          0.0          0.0       0.000000  ...
# 390          0.0            3.0          0.0          0.0       0.000000  ...
# 521          0.0            3.0          0.0          0.0       0.000000  ...
# 407          0.0            3.0          0.0          0.0       0.666667  ...
# 506          0.0            3.0          0.0          0.0       0.000000  ...
# 235          0.0            3.0          0.0          0.0       1.000000  ...
# 304          1.0            3.0          0.0          1.0       0.000000  ...
# 303          0.0            3.0          0.0          0.0       0.000000  ...
# 4            0.0            3.0          0.0          0.0       0.666667  ...
# 251          0.0            3.0          0.0          0.0       0.000000  ...
# 248          0.0            3.0          0.0          0.0       0.000000  ...
# 364          0.0            3.0          0.0          0.0       0.000000  ...
# 51           0.0            3.0          0.0          0.0       0.000000  ...
# 395          0.0            3.0          0.0          0.0       0.000000  ...
# 302          0.0            3.0          0.0          0.0       0.000000  ...
#
#      value_form  value_season          web_name  yellow_cards  position  \
# 361         0.2           0.4            Aarons             1  Defender
# 9           0.3           0.9        Adam Smith             1  Defender
# 387         0.3           0.8               Aké             1  Defender
# 491         0.3           0.9      Alderweireld             0  Defender
# 497         0.5           1.6  Alexander-Arnold             1  Defender
# 331         0.0           0.2            Alonso             0  Defender
# 108         0.3           1.0       Azpilicueta             0  Defender
# 165        -0.1          -0.2          Balbuena             1  Defender
# 182         1.0           3.1           Baldock             1  Defender
# 96          0.7           2.0            Basham             0  Defender
# 236         0.7           2.0          Bednarek             0  Defender
# 450         0.6           1.8           Bennett             1  Defender
# 69          0.1           0.2          Bernardo             0  Defender
# 451         0.1           0.4          Bertrand             0  Defender
# 515         1.0           3.0              Boly             0  Defender
# 119         0.7           2.0              Burn             0  Defender
# 458         0.1           0.2             Byram             0  Defender
# 179         0.1           0.2            Cahill             1  Defender
# 281         0.1           0.2           Cancelo             0  Defender
# 105         0.3           0.9          Cathcart             0  Defender
# 79          0.4           1.3          Chambers             0  Defender
# 58          0.4           1.1          Chilwell             0  Defender
# 27          0.2           0.6       Christensen             0  Defender
# 103         0.7           2.0             Coady             0  Defender
# 464         0.7           2.0           Coleman             2  Defender
# 0           0.0           0.0         Cresswell             0  Defender
# 85          0.2           0.7           Daniels             0  Defender
# 461         0.6           1.8              Dann             0  Defender
# 294         0.7           1.3             Danso             0  Defender
# 126         0.0           0.2        David Luiz             2  Defender
# ..          ...           ...               ...           ...       ...
# 158         1.2           3.7           Pieters             0  Defender
# 138         0.2           0.5              Rico             0  Defender
# 359         0.5           1.5           Ritchie             1  Defender
# 29          0.3           0.9         Robertson             0  Defender
# 116         0.2           0.7              Rose             1  Defender
# 445         0.1           0.2             Saïss             0  Defender
# 163         0.7           2.2             Schär             0  Defender
# 325         0.5           1.6              Shaw             0  Defender
# 477         0.7           2.2          Sokratis             0  Defender
# 218         0.1           0.2          Stephens             0  Defender
# 480         0.3           1.0        Steve Cook             0  Defender
# 154         0.7           2.0           Stevens             0  Defender
# 259         0.4           1.1            Stones             0  Defender
# 129         0.3           0.9           Sánchez             0  Defender
# 526         1.0           2.9           Söyüncü             0  Defender
# 231         0.5           1.6         Tarkowski             1  Defender
# 390         0.6           1.8            Taylor             0  Defender
# 521         0.2           0.6            Valery             0  Defender
# 407         1.1           3.3       van Aanholt             0  Defender
# 506         0.6           1.8          van Dijk             0  Defender
# 235         0.7           2.2       Vestergaard             0  Defender
# 304         0.6           1.7            Walker             2  Defender
# 303         0.3           1.0     Walker-Peters             0  Defender
# 4           0.5           1.6       Wan-Bissaka             2  Defender
# 251         0.7           2.2              Ward             0  Defender
# 248         0.1           0.2           Willems             0  Defender
# 364         0.1           0.2           Yoshida             0  Defender
# 51          0.1           0.2             Young             0  Defender
# 395         0.5           1.6         Zinchenko             0  Defender
# 302         0.1           0.4             Zouma             1  Defender
#
#      minutes_points    web_name_lower  achievements    errors         value
# 361        6.000000            aarons      2.000000  3.000000 -1.000000e+00
# 9          5.488889        adam smith      1.829630  2.000000 -1.703704e-01
# 387        6.000000               aké      2.000000  2.000000  0.000000e+00
# 491        6.000000      alderweireld      2.000000  1.333333  6.666667e-01
# 497        6.000000  alexander-arnold      4.000000  1.333333  2.666667e+00
# 331        0.022222            alonso      0.007407  0.000000  7.407407e-03
# 108        6.000000       azpilicueta      3.000000  2.333333  6.666667e-01
# 165        2.000000          balbuena      0.666667  2.000000 -1.333333e+00
# 182        6.000000           baldock      4.333333  1.333333  3.000000e+00
# 96         5.511111            basham      3.170370  1.000000  2.170370e+00
# 236        6.000000          bednarek      3.333333  1.666667  1.666667e+00
# 450        6.000000           bennett      3.333333  1.000000  2.333333e+00
# 69         0.022222          bernardo      0.007407  0.000000  7.407407e-03
# 451        3.688889          bertrand      1.229630  1.666667 -4.370370e-01
# 515        6.000000              boly      3.333333  0.666667  2.666667e+00
# 119        6.000000              burn      3.333333  1.000000  2.333333e+00
# 458        0.022222             byram      0.007407  0.333333 -3.259259e-01
# 179        2.000000            cahill      0.666667  0.666667  1.110223e-16
# 281        0.022222           cancelo      0.007407  0.000000  7.407407e-03
# 105        6.000000          cathcart      2.000000  2.333333 -3.333333e-01
# 79         2.000000          chambers      2.000000  0.000000  2.000000e+00
# 58         2.000000          chilwell      2.000000  0.000000  2.000000e+00
# 27         6.000000       christensen      2.000000  2.333333 -3.333333e-01
# 103        6.000000             coady      3.333333  0.666667  2.666667e+00
# 464        6.000000           coleman      4.666667  1.333333  3.333333e+00
# 0          2.000000         cresswell      0.666667  1.666667 -1.000000e+00
# 85         2.800000           daniels      0.933333  0.666667  2.666667e-01
# 461        4.000000              dann      2.666667  0.333333  2.333333e+00
# 294        2.000000             danso      3.000000  0.000000  3.000000e+00
# 126        4.000000        david luiz      1.333333  2.000000 -6.666667e-01
# ..              ...               ...           ...       ...           ...
# 158        6.000000           pieters      5.333333  1.000000  4.333333e+00
# 138        2.000000              rico      0.666667  0.333333  3.333333e-01
# 359        6.000000           ritchie      3.333333  1.666667  1.666667e+00
# 29         6.000000         robertson      2.000000  1.000000  1.000000e+00
# 116        5.933333              rose      1.977778  1.666667  3.111111e-01
# 445        0.200000             saïss      0.066667  0.000000  6.666667e-02
# 163        6.000000             schär      3.333333  1.333333  2.000000e+00
# 325        4.733333              shaw      2.911111  0.666667  2.244444e+00
# 477        6.000000          sokratis      3.333333  1.333333  2.000000e+00
# 218        1.600000          stephens      0.533333  0.666667 -1.333333e-01
# 480        6.000000        steve cook      2.000000  1.666667  3.333333e-01
# 154        6.000000           stevens      3.333333  1.000000  2.333333e+00
# 259        2.000000            stones      2.000000  0.000000  2.000000e+00
# 129        6.000000           sánchez      2.000000  1.333333  6.666667e-01
# 526        6.000000           söyüncü      4.333333  0.666667  3.666667e+00
# 231        6.000000         tarkowski      3.333333  1.333333  2.000000e+00
# 390        6.000000            taylor      3.333333  1.666667  1.666667e+00
# 521        5.155556            valery      1.718519  1.666667  5.185185e-02
# 407        6.000000       van aanholt      5.333333  0.666667  4.666667e+00
# 506        6.000000          van dijk      4.000000  1.000000  3.000000e+00
# 235        6.000000       vestergaard      3.333333  1.666667  1.666667e+00
# 304        5.977778            walker      4.325926  1.666667  2.659259e+00
# 303        5.355556     walker-peters      1.785185  1.333333  4.518519e-01
# 4          6.000000       wan-bissaka      3.333333  1.666667  1.666667e+00
# 251        6.000000              ward      3.333333  0.666667  2.666667e+00
# 248        0.800000           willems      0.266667  0.333333 -6.666667e-02
# 364        2.000000           yoshida      0.666667  0.666667  1.110223e-16
# 51         1.244444             young      0.414815  0.333333  8.148148e-02
# 395        6.000000         zinchenko      3.333333  1.000000  2.333333e+00
# 302        6.000000             zouma      2.000000  2.666667 -6.666667e-01
#
# [111 rows x 200 columns]

# %%
game_metrics_mid = points_metrics + general_metrics + creativity_metrics + attack_metrics
game_metrics_mid = set(game_metrics_mid)

game_metrics_mid = get_agg_features(game_metrics_mid, ['sum','average'])

points_mid = points.copy()
points_mid['goals_scored']=5
points_mid['clean_sheets']=1
points_mid['goals_conceded']=0

generate_performance_plots(points_mid, midfielders, 'Midfielder')
# Out:
#                                          name_id   id  \
# 335                          Marc_Albrighton_174  174
# 372                           Miguel_Almirón_266  266
# 35                André Filipe_Tavares Gomes_422  422
# 370                          Michail_Antonio_389  389
# 481                         Stuart_Armstrong_323  323
# 89                            Christian_Atsu_267  267
# 447                             Ross_Barkley_117  117
# 196                            Harvey_Barnes_172  172
# 70            Bernard_Anício Caldeira Duarte_152  152
# 68   Bernardo Mota_Veiga de Carvalho e Silva_218  218
# 414                           Philip_Billing_476  476
# 476                           Sofiane_Boufal_508  508
# 151                         Emiliano_Buendía_283  283
# 492                            Todd_Cantwell_287  287
# 160                           Etienne_Capoue_373  373
# 81                            Carlos_Sánchez_397  397
# 111                Daniel_Ceballos Fernández_469  469
# 23                   Alex_Oxlade-Chamberlain_193  193
# 191                          Hamza_Choudhury_180  180
# 493                            Tom_Cleverley_371  371
# 213                                Jack_Cork_102  102
# 128                              David_Silva_219  219
# 494                               Tom_Davies_154  154
# 289                              Keinan_Davis_34   34
# 295                          Kevin_De Bruyne_215  215
# 306                       Leander_Dendoncker_420  420
# 380                           Moussa_Djenepo_438  438
# 5                         Abdoulaye_Doucouré_368  368
# 145             Douglas Luiz_Soares de Paulo_470  470
# 45                             Anwar_El Ghazi_30   30
# ..                                           ...  ...
# 263                            Jonjo_Shelvey_269  269
# 190                         Gylfi_Sigurdsson_151  151
# 381                           Moussa_Sissoko_349  349
# 398                             Oliver_Skipp_352  352
# 441                         Robert_Snodgrass_393  393
# 199                            Heung-Min_Son_342  342
# 109                             Dale_Stephens_57   57
# 425                          Raheem_Sterling_214  214
# 333                        Marco_Stiepermann_285  285
# 30                              Andrew_Surman_80   80
# 17                          Alexander_Tettey_289  289
# 524                          Youri_Tielemans_448  448
# 319                            Lucas_Torreira_19   19
# 34                           Andros_Townsend_135  135
# 6                               Adama_Traoré_417  417
# 307                         Leandro_Trossard_421  421
# 496                              Tom_Trybull_290  290
# 328             Mahmoud Ahmed_Ibrahim Hassan_465  465
# 338                            Mario_Vrancic_282  282
# 488                             Theo_Walcott_153  153
# 233                        James_Ward-Prowse_321  321
# 50                           Ashley_Westwood_101  101
# 183                      Georginio_Wijnaldum_199  199
# 514                  Willian_Borges Da Silva_113  113
# 272                           Joseph_Willock_490  490
# 219                            Jack_Wilshere_394  394
# 195                              Harry_Winks_347  347
# 188                              Granit_Xhaka_18   18
# 33                         Andriy_Yarmolenko_392  392
# 513                            Wilfried_Zaha_133  133
#
#                                         name  average_assists  median_assists  \
# 335                          Marc Albrighton         0.000000             0.0
# 372                           Miguel Almirón         0.000000             0.0
# 35                André Filipe Tavares Gomes         0.000000             0.0
# 370                          Michail Antonio         0.333333             0.0
# 481                         Stuart Armstrong         0.000000             0.0
# 89                            Christian Atsu         0.333333             0.0
# 447                             Ross Barkley         0.000000             0.0
# 196                            Harvey Barnes         0.000000             0.0
# 70            Bernard Anício Caldeira Duarte         0.000000             0.0
# 68   Bernardo Mota Veiga de Carvalho e Silva         0.000000             0.0
# 414                           Philip Billing         0.000000             0.0
# 476                           Sofiane Boufal         0.333333             0.0
# 151                         Emiliano Buendía         0.666667             1.0
# 492                            Todd Cantwell         0.666667             0.0
# 160                           Etienne Capoue         0.000000             0.0
# 81                            Carlos Sánchez         0.000000             0.0
# 111                Daniel Ceballos Fernández         0.666667             0.0
# 23                   Alex Oxlade-Chamberlain         0.000000             0.0
# 191                          Hamza Choudhury         0.000000             0.0
# 493                            Tom Cleverley         0.000000             0.0
# 213                                Jack Cork         0.000000             0.0
# 128                              David Silva         0.666667             0.0
# 494                               Tom Davies         0.000000             0.0
# 289                             Keinan Davis         0.000000             0.0
# 295                          Kevin De Bruyne         1.333333             1.0
# 306                       Leander Dendoncker         0.000000             0.0
# 380                           Moussa Djenepo         0.000000             0.0
# 5                         Abdoulaye Doucouré         0.000000             0.0
# 145             Douglas Luiz Soares de Paulo         0.000000             0.0
# 45                            Anwar El Ghazi         0.000000             0.0
# ..                                       ...              ...             ...
# 263                            Jonjo Shelvey         0.000000             0.0
# 190                         Gylfi Sigurdsson         0.000000             0.0
# 381                           Moussa Sissoko         0.333333             0.0
# 398                             Oliver Skipp         0.000000             0.0
# 441                         Robert Snodgrass         0.000000             0.0
# 199                            Heung-Min Son         0.000000             0.0
# 109                            Dale Stephens         0.000000             0.0
# 425                          Raheem Sterling         0.000000             0.0
# 333                        Marco Stiepermann         0.000000             0.0
# 30                             Andrew Surman         0.000000             0.0
# 17                          Alexander Tettey         0.000000             0.0
# 524                          Youri Tielemans         0.000000             0.0
# 319                           Lucas Torreira         0.000000             0.0
# 34                           Andros Townsend         0.000000             0.0
# 6                               Adama Traoré         0.000000             0.0
# 307                         Leandro Trossard         0.000000             0.0
# 496                              Tom Trybull         0.000000             0.0
# 328             Mahmoud Ahmed Ibrahim Hassan         0.000000             0.0
# 338                            Mario Vrancic         0.000000             0.0
# 488                             Theo Walcott         0.000000             0.0
# 233                        James Ward-Prowse         0.000000             0.0
# 50                           Ashley Westwood         0.000000             0.0
# 183                      Georginio Wijnaldum         0.000000             0.0
# 514                  Willian Borges Da Silva         0.000000             0.0
# 272                           Joseph Willock         0.000000             0.0
# 219                            Jack Wilshere         0.000000             0.0
# 195                              Harry Winks         0.000000             0.0
# 188                             Granit Xhaka         0.000000             0.0
# 33                         Andriy Yarmolenko         0.000000             0.0
# 513                            Wilfried Zaha         0.000000             0.0
#
#      sum_assists  count_assists  min_assists  max_assists  average_bonus  ...  \
# 335          0.0            3.0          0.0          0.0       0.000000  ...
# 372          0.0            3.0          0.0          0.0       0.000000  ...
# 35           0.0            3.0          0.0          0.0       0.000000  ...
# 370          1.0            3.0          0.0          1.0       0.000000  ...
# 481          0.0            3.0          0.0          0.0       0.000000  ...
# 89           1.0            3.0          0.0          1.0       0.000000  ...
# 447          0.0            3.0          0.0          0.0       0.000000  ...
# 196          0.0            3.0          0.0          0.0       0.000000  ...
# 70           0.0            3.0          0.0          0.0       1.000000  ...
# 68           0.0            3.0          0.0          0.0       0.000000  ...
# 414          0.0            3.0          0.0          0.0       0.000000  ...
# 476          1.0            3.0          0.0          1.0       0.000000  ...
# 151          2.0            3.0          0.0          1.0       0.000000  ...
# 492          2.0            3.0          0.0          2.0       0.666667  ...
# 160          0.0            3.0          0.0          0.0       0.000000  ...
# 81           0.0            3.0          0.0          0.0       0.000000  ...
# 111          2.0            3.0          0.0          2.0       1.000000  ...
# 23           0.0            3.0          0.0          0.0       0.000000  ...
# 191          0.0            3.0          0.0          0.0       0.000000  ...
# 493          0.0            3.0          0.0          0.0       0.000000  ...
# 213          0.0            3.0          0.0          0.0       0.000000  ...
# 128          2.0            3.0          0.0          2.0       0.666667  ...
# 494          0.0            3.0          0.0          0.0       0.000000  ...
# 289          0.0            3.0          0.0          0.0       0.000000  ...
# 295          4.0            3.0          1.0          2.0       1.333333  ...
# 306          0.0            3.0          0.0          0.0       0.000000  ...
# 380          0.0            3.0          0.0          0.0       0.000000  ...
# 5            0.0            3.0          0.0          0.0       0.000000  ...
# 145          0.0            3.0          0.0          0.0       0.666667  ...
# 45           0.0            3.0          0.0          0.0       0.000000  ...
# ..           ...            ...          ...          ...            ...  ...
# 263          0.0            3.0          0.0          0.0       0.333333  ...
# 190          0.0            3.0          0.0          0.0       0.000000  ...
# 381          1.0            3.0          0.0          1.0       0.000000  ...
# 398          0.0            3.0          0.0          0.0       0.000000  ...
# 441          0.0            3.0          0.0          0.0       0.000000  ...
# 199          0.0            3.0          0.0          0.0       0.000000  ...
# 109          0.0            3.0          0.0          0.0       0.000000  ...
# 425          0.0            3.0          0.0          0.0       1.333333  ...
# 333          0.0            3.0          0.0          0.0       0.000000  ...
# 30           0.0            3.0          0.0          0.0       0.000000  ...
# 17           0.0            3.0          0.0          0.0       0.000000  ...
# 524          0.0            3.0          0.0          0.0       0.000000  ...
# 319          0.0            3.0          0.0          0.0       0.000000  ...
# 34           0.0            3.0          0.0          0.0       0.000000  ...
# 6            0.0            3.0          0.0          0.0       0.000000  ...
# 307          0.0            3.0          0.0          0.0       0.000000  ...
# 496          0.0            3.0          0.0          0.0       0.000000  ...
# 328          0.0            3.0          0.0          0.0       0.000000  ...
# 338          0.0            3.0          0.0          0.0       0.000000  ...
# 488          0.0            3.0          0.0          0.0       0.000000  ...
# 233          0.0            3.0          0.0          0.0       0.000000  ...
# 50           0.0            3.0          0.0          0.0       0.000000  ...
# 183          0.0            3.0          0.0          0.0       0.000000  ...
# 514          0.0            3.0          0.0          0.0       0.000000  ...
# 272          0.0            3.0          0.0          0.0       0.000000  ...
# 219          0.0            3.0          0.0          0.0       0.000000  ...
# 195          0.0            3.0          0.0          0.0       0.000000  ...
# 188          0.0            3.0          0.0          0.0       0.000000  ...
# 33           0.0            3.0          0.0          0.0       0.000000  ...
# 513          0.0            3.0          0.0          0.0       0.000000  ...
#
#      value_form  value_season        web_name  yellow_cards    position  \
# 335         0.1           0.4      Albrighton             0  Midfielder
# 372         0.3           1.0         Almirón             1  Midfielder
# 35          0.2           0.7     André Gomes             2  Midfielder
# 370         0.3           0.9         Antonio             0  Midfielder
# 481         0.1           0.4       Armstrong             0  Midfielder
# 89          0.4           1.1            Atsu             0  Midfielder
# 447         0.2           0.5         Barkley             0  Midfielder
# 196         0.4           1.2          Barnes             0  Midfielder
# 70          0.8           2.3         Bernard             1  Midfielder
# 68          0.2           0.5  Bernardo Silva             0  Midfielder
# 414         0.3           0.8         Billing             1  Midfielder
# 476         0.3           0.9          Boufal             0  Midfielder
# 151         0.6           1.8         Buendía             1  Midfielder
# 492         1.4           4.1        Cantwell             0  Midfielder
# 160         0.3           1.0          Capoue             1  Midfielder
# 81          0.2           0.4  Carlos Sánchez             0  Midfielder
# 111         0.8           2.5        Ceballos             0  Midfielder
# 23          0.2           0.5     Chamberlain             0  Midfielder
# 191         0.5           1.6       Choudhury             0  Midfielder
# 493         0.2           0.6       Cleverley             0  Midfielder
# 213         0.5           1.4            Cork             0  Midfielder
# 128         0.6           1.9     David Silva             0  Midfielder
# 494         0.1           0.2          Davies             0  Midfielder
# 289         0.1           0.2           Davis             0  Midfielder
# 295         0.8           2.4       De Bruyne             0  Midfielder
# 306         0.4           1.3      Dendoncker             0  Midfielder
# 380         0.3           0.9         Djenepo             2  Midfielder
# 5           0.2           0.7        Doucouré             0  Midfielder
# 145         1.0           2.9    Douglas Luiz             0  Midfielder
# 45          0.6           1.8        El Ghazi             0  Midfielder
# ..          ...           ...             ...           ...         ...
# 263         0.6           1.8         Shelvey             0  Midfielder
# 190         0.3           1.0      Sigurdsson             0  Midfielder
# 381         0.6           1.8         Sissoko             0  Midfielder
# 398         0.2           0.4           Skipp             0  Midfielder
# 441         0.2           0.5       Snodgrass             0  Midfielder
# 199         0.1           0.2             Son             0  Midfielder
# 109         0.5           1.6        Stephens             0  Midfielder
# 425         0.9           2.8        Sterling             2  Midfielder
# 333         0.3           0.9     Stiepermann             1  Midfielder
# 30          0.1           0.2          Surman             0  Midfielder
# 17          0.1           0.2          Tettey             0  Midfielder
# 524         0.4           1.1       Tielemans             0  Midfielder
# 319         0.5           1.4        Torreira             0  Midfielder
# 34          0.3           1.0        Townsend             0  Midfielder
# 6           0.1           0.4          Traoré             0  Midfielder
# 307         0.5           1.5        Trossard             0  Midfielder
# 496         0.5           1.6         Trybull             0  Midfielder
# 328         0.3           0.9       Trézéguet             1  Midfielder
# 338         0.1           0.3         Vrancic             0  Midfielder
# 488         0.1           0.3         Walcott             0  Midfielder
# 233         0.3           1.0     Ward-Prowse             1  Midfielder
# 50          0.4           1.3        Westwood             0  Midfielder
# 183         0.4           1.3       Wijnaldum             0  Midfielder
# 514         0.1           0.3         Willian             0  Midfielder
# 272         0.5           1.4         Willock             0  Midfielder
# 219         0.1           0.4        Wilshere             0  Midfielder
# 195         0.2           0.7           Winks             1  Midfielder
# 188         0.2           0.7           Xhaka             1  Midfielder
# 33          0.1           0.3      Yarmolenko             0  Midfielder
# 513         0.2           0.6            Zaha             1  Midfielder
#
#      minutes_points  web_name_lower  achievements    errors      value
# 335        0.533333      albrighton      0.177778  0.000000   0.177778
# 372        6.000000         almirón      2.333333  0.333333   2.000000
# 35         5.000000     andré gomes      2.000000  0.666667   1.333333
# 370        2.777778         antonio      1.925926  0.000000   1.925926
# 481        0.622222       armstrong      0.207407  0.000000   0.207407
# 89         1.622222            atsu      1.874074  0.000000   1.874074
# 447        3.266667         barkley      1.088889  0.000000   1.088889
# 196        1.222222          barnes      2.074074  0.000000   2.074074
# 70         5.355556         bernard      4.118519  0.333333   3.785185
# 68         3.488889  bernardo silva      1.162963  0.000000   1.162963
# 414        5.000000         billing      1.666667  0.333333   1.333333
# 476        0.600000          boufal      1.200000  0.000000   1.200000
# 151        6.000000         buendía      4.000000  0.333333   3.666667
# 492        6.000000        cantwell      5.666667  0.000000   5.666667
# 160        5.822222          capoue      1.940741  0.333333   1.607407
# 81         0.200000  carlos sánchez      0.066667  0.000000   0.066667
# 111        3.733333        ceballos      3.244444  0.000000   3.244444
# 23         2.244444     chamberlain      0.748148  0.000000   0.748148
# 191        4.933333       choudhury      1.977778  0.000000   1.977778
# 493        2.133333       cleverley      0.711111  0.000000   0.711111
# 213        6.000000            cork      2.333333  0.000000   2.333333
# 128        4.022222     david silva      3.674074  0.000000   3.674074
# 494        0.244444          davies      0.081481  0.000000   0.081481
# 289        0.066667           davis      0.022222  0.000000   0.022222
# 295        5.733333       de bruyne      6.244444  0.000000   6.244444
# 306        4.688889      dendoncker      1.896296  0.000000   1.896296
# 380        1.111111         djenepo      2.037037  0.666667   1.370370
# 5          6.000000        doucouré      2.000000  0.666667   1.333333
# 145        4.177778    douglas luiz      3.392593  0.000000   3.392593
# 45         3.933333        el ghazi      2.977778  0.000000   2.977778
# ..              ...             ...           ...       ...        ...
# 263        3.177778         shelvey      2.725926  0.000000   2.725926
# 190        5.088889      sigurdsson      2.362963  0.000000   2.362963
# 381        6.000000         sissoko      3.000000  0.000000   3.000000
# 398        0.044444           skipp      0.014815  0.000000   0.014815
# 441        2.755556       snodgrass      0.918519  0.000000   0.918519
# 199        2.000000             son      0.666667  0.000000   0.666667
# 109        5.711111        stephens      2.237037  0.000000   2.237037
# 425        6.000000        sterling     10.666667  0.666667  10.000000
# 333        4.888889     stiepermann      1.962963  0.333333   1.629630
# 30         1.000000          surman      0.333333  0.000000   0.333333
# 17         0.066667          tettey      0.022222  0.000000   0.022222
# 524        5.955556       tielemans      2.318519  0.000000   2.318519
# 319        0.800000        torreira      1.933333  0.000000   1.933333
# 34         3.755556        townsend      1.585185  0.000000   1.585185
# 6          1.311111          traoré      0.437037  0.000000   0.437037
# 307        3.866667        trossard      2.955556  0.000000   2.955556
# 496        5.222222         trybull      2.074074  0.000000   2.074074
# 328        5.088889       trézéguet      2.029630  0.333333   1.696296
# 338        0.333333         vrancic      0.111111  0.000000   0.111111
# 488        0.866667         walcott      0.288889  0.000000   0.288889
# 233        6.000000     ward-prowse      2.333333  0.333333   2.000000
# 50         6.000000        westwood      2.333333  0.000000   2.333333
# 183        5.511111       wijnaldum      2.170370  0.000000   2.170370
# 514        0.555556         willian      0.185185  0.000000   0.185185
# 272        5.177778         willock      2.059259  0.000000   2.059259
# 219        2.222222        wilshere      0.740741  0.000000   0.740741
# 195        4.622222           winks      1.540741  0.333333   1.207407
# 188        4.000000           xhaka      1.666667  0.333333   1.333333
# 33         1.488889      yarmolenko      0.496296  0.000000   0.496296
# 513        4.555556            zaha      1.518519  0.333333   1.185185
#
# [152 rows x 200 columns]

# %%
game_metrics_fwd = points_metrics + general_metrics + creativity_metrics + attack_metrics
game_metrics_fwd = set(game_metrics_fwd)
game_metrics_fwd = get_agg_features(game_metrics_fwd, ['sum', 'average'])

points_fwd = points.copy()
points_fwd['goals_scored'] = 4
points_fwd['clean_sheets'] = 0
points_fwd['goals_conceded'] = 0

generate_performance_plots(points_fwd, forwards, 'Forward')
# Out:
#                                      name_id   id  \
# 485                        Tammy_Abraham_460  460
# 88                             Che_Adams_437  437
# 468                        Sergio_Agüero_210  210
# 171                         Florin_Andone_46   46
# 420             Pierre-Emerick_Aubameyang_11   11
# 265                          Jordan_Ayew_468  468
# 49                          Ashley_Barnes_90   90
# 90                     Christian_Benteke_129  129
# 78                          Callum_Wilson_67   67
# 143                Dominic_Calvert-Lewin_147  147
# 238            Javier_Hernández Balcázar_386  386
# 405                      Patrick_Cutrone_487  487
# 498                          Troy_Deeney_362  362
# 184                      Gerard_Deulofeu_363  363
# 274                          Josip_Drmic_434  434
# 438                      Roberto_Firmino_187  187
# 399                       Olivier_Giroud_110  110
# 31                            Andre_Gray_364  364
# 347                      Mason_Greenwood_234  234
# 483                     Sébastien_Haller_457  457
# 115                           Danny_Ings_313  313
# 177            Gabriel Fernando_de Jesus_211  211
# 428                         Raúl_Jiménez_409  409
# 249  Joelinton Cássio_Apolinário de Lira_466  466
# 139                           Diogo_Jota_410  410
# 192                           Harry_Kane_338  338
# 376                           Moise_Kean_496  496
# 273                           Joshua_King_68   68
# 262                       Jonathan_Kodjia_26   26
# 19                    Alexandre_Lacazette_12   12
# 285                        Jürgen_Locadia_45   45
# 178     Gabriel Teodoro_Martinelli Silva_504  504
# 389                          Neal_Maupay_502  502
# 396                      Oliver_McBurnie_501  501
# 127                     David_McGoldrick_303  303
# 186                          Glenn_Murray_44   44
# 523                       Yoshinori_Muto_260  260
# 368                      Michael_Obafemi_314  314
# 140                         Divock_Origi_188  188
# 487                          Teemu_Pukki_278  278
# 334                      Marcus_Rashford_233  233
# 240                        Jay_Rodriguez_451  451
# 72                           Billy_Sharp_298  298
# 144                       Dominic_Solanke_69   69
# 137                        Dennis_Srbeny_279  279
# 208                  Isaac_Success Ajayi_365  365
# 234                          Jamie_Vardy_166  166
# 118                        Danny_Welbeck_512  512
# 510                        Wesley_Moraes_428  428
# 102                       Connor_Wickham_130  130
# 99                             Chris_Wood_91   91
#
#                                     name  average_assists  median_assists  \
# 485                        Tammy Abraham         0.000000             0.0
# 88                             Che Adams         0.000000             0.0
# 468                        Sergio Agüero         0.000000             0.0
# 171                        Florin Andone         0.000000             0.0
# 420            Pierre-Emerick Aubameyang         0.333333             0.0
# 265                          Jordan Ayew         0.000000             0.0
# 49                         Ashley Barnes         0.000000             0.0
# 90                     Christian Benteke         0.000000             0.0
# 78                         Callum Wilson         1.000000             1.0
# 143                Dominic Calvert-Lewin         0.000000             0.0
# 238            Javier Hernández Balcázar         0.000000             0.0
# 405                      Patrick Cutrone         0.000000             0.0
# 498                          Troy Deeney         0.000000             0.0
# 184                      Gerard Deulofeu         0.000000             0.0
# 274                          Josip Drmic         0.000000             0.0
# 438                      Roberto Firmino         0.333333             0.0
# 399                       Olivier Giroud         0.000000             0.0
# 31                            Andre Gray         0.000000             0.0
# 347                      Mason Greenwood         0.000000             0.0
# 483                     Sébastien Haller         0.000000             0.0
# 115                           Danny Ings         0.333333             0.0
# 177            Gabriel Fernando de Jesus         0.000000             0.0
# 428                         Raúl Jiménez         0.000000             0.0
# 249  Joelinton Cássio Apolinário de Lira         0.000000             0.0
# 139                           Diogo Jota         0.000000             0.0
# 192                           Harry Kane         0.000000             0.0
# 376                           Moise Kean         0.000000             0.0
# 273                          Joshua King         0.000000             0.0
# 262                      Jonathan Kodjia         0.000000             0.0
# 19                   Alexandre Lacazette         0.000000             0.0
# 285                       Jürgen Locadia         0.000000             0.0
# 178     Gabriel Teodoro Martinelli Silva         0.000000             0.0
# 389                          Neal Maupay         0.000000             0.0
# 396                      Oliver McBurnie         0.000000             0.0
# 127                     David McGoldrick         0.000000             0.0
# 186                         Glenn Murray         0.000000             0.0
# 523                       Yoshinori Muto         0.000000             0.0
# 368                      Michael Obafemi         0.000000             0.0
# 140                         Divock Origi         0.333333             0.0
# 487                          Teemu Pukki         0.333333             0.0
# 334                      Marcus Rashford         0.333333             0.0
# 240                        Jay Rodriguez         0.000000             0.0
# 72                           Billy Sharp         0.000000             0.0
# 144                      Dominic Solanke         0.000000             0.0
# 137                        Dennis Srbeny         0.000000             0.0
# 208                  Isaac Success Ajayi         0.000000             0.0
# 234                          Jamie Vardy         0.000000             0.0
# 118                        Danny Welbeck         0.000000             0.0
# 510                        Wesley Moraes         0.000000             0.0
# 102                       Connor Wickham         0.000000             0.0
# 99                            Chris Wood         0.000000             0.0
#
#      sum_assists  count_assists  min_assists  max_assists  average_bonus  ...  \
# 485          0.0            3.0          0.0          0.0       1.000000  ...
# 88           0.0            3.0          0.0          0.0       0.000000  ...
# 468          0.0            3.0          0.0          0.0       1.000000  ...
# 171          0.0            3.0          0.0          0.0       0.333333  ...
# 420          1.0            3.0          0.0          1.0       0.333333  ...
# 265          0.0            3.0          0.0          0.0       1.000000  ...
# 49           0.0            3.0          0.0          0.0       1.333333  ...
# 90           0.0            3.0          0.0          0.0       0.000000  ...
# 78           3.0            3.0          1.0          1.0       0.000000  ...
# 143          0.0            3.0          0.0          0.0       0.000000  ...
# 238          0.0            3.0          0.0          0.0       0.666667  ...
# 405          0.0            3.0          0.0          0.0       0.000000  ...
# 498          0.0            3.0          0.0          0.0       0.000000  ...
# 184          0.0            3.0          0.0          0.0       0.000000  ...
# 274          0.0            3.0          0.0          0.0       0.000000  ...
# 438          1.0            3.0          0.0          1.0       0.666667  ...
# 399          0.0            3.0          0.0          0.0       0.000000  ...
# 31           0.0            3.0          0.0          0.0       0.666667  ...
# 347          0.0            3.0          0.0          0.0       0.000000  ...
# 483          0.0            3.0          0.0          0.0       1.000000  ...
# 115          1.0            3.0          0.0          1.0       0.333333  ...
# 177          0.0            3.0          0.0          0.0       0.000000  ...
# 428          0.0            3.0          0.0          0.0       1.000000  ...
# 249          0.0            3.0          0.0          0.0       1.000000  ...
# 139          0.0            3.0          0.0          0.0       0.000000  ...
# 192          0.0            3.0          0.0          0.0       1.000000  ...
# 376          0.0            3.0          0.0          0.0       0.000000  ...
# 273          0.0            3.0          0.0          0.0       0.000000  ...
# 262          0.0            3.0          0.0          0.0       0.000000  ...
# 19           0.0            3.0          0.0          0.0       0.666667  ...
# 285          0.0            3.0          0.0          0.0       0.000000  ...
# 178          0.0            3.0          0.0          0.0       0.000000  ...
# 389          0.0            3.0          0.0          0.0       0.333333  ...
# 396          0.0            3.0          0.0          0.0       0.333333  ...
# 127          0.0            3.0          0.0          0.0       0.000000  ...
# 186          0.0            3.0          0.0          0.0       0.000000  ...
# 523          0.0            3.0          0.0          0.0       0.000000  ...
# 368          0.0            3.0          0.0          0.0       0.000000  ...
# 140          1.0            3.0          0.0          1.0       1.000000  ...
# 487          1.0            3.0          0.0          1.0       2.000000  ...
# 334          1.0            3.0          0.0          1.0       1.333333  ...
# 240          0.0            3.0          0.0          0.0       0.000000  ...
# 72           0.0            3.0          0.0          0.0       1.000000  ...
# 144          0.0            3.0          0.0          0.0       0.000000  ...
# 137          0.0            3.0          0.0          0.0       0.000000  ...
# 208          0.0            3.0          0.0          0.0       0.000000  ...
# 234          0.0            3.0          0.0          0.0       0.666667  ...
# 118          0.0            3.0          0.0          0.0       0.000000  ...
# 510          0.0            3.0          0.0          0.0       1.000000  ...
# 102          0.0            3.0          0.0          0.0       0.000000  ...
# 99           0.0            3.0          0.0          0.0       0.000000  ...
#
#      value_form  value_season       web_name  yellow_cards  position  \
# 485         0.7           2.1        Abraham             1   Forward
# 88          0.3           1.0          Adams             0   Forward
# 468         0.7           2.0         Agüero             0   Forward
# 171         0.3           1.0         Andone             0   Forward
# 420         0.5           1.5     Aubameyang             1   Forward
# 265         0.7           2.2           Ayew             0   Forward
# 49          1.3           3.8         Barnes             1   Forward
# 90          0.3           0.8        Benteke             0   Forward
# 78          0.6           1.9  Callum Wilson             0   Forward
# 143         0.3           0.8  Calvert-Lewin             1   Forward
# 238         0.5           1.5     Chicharito             0   Forward
# 405         0.1           0.3        Cutrone             0   Forward
# 498         0.2           0.6         Deeney             0   Forward
# 184         0.3           0.8       Deulofeu             0   Forward
# 274         0.1           0.2          Drmic             0   Forward
# 438         0.5           1.6        Firmino             0   Forward
# 399         0.2           0.6         Giroud             0   Forward
# 31          0.6           1.9           Gray             0   Forward
# 347         0.2           0.7      Greenwood             0   Forward
# 483         0.7           2.0         Haller             0   Forward
# 115         0.7           2.2           Ings             0   Forward
# 177         0.2           0.7          Jesus             0   Forward
# 428         0.6           1.8        Jiménez             0   Forward
# 249         0.6           1.9      Joelinton             2   Forward
# 139         0.3           0.9           Jota             0   Forward
# 192         0.5           1.5           Kane             0   Forward
# 376         0.1           0.4           Kean             0   Forward
# 273         0.5           1.6           King             0   Forward
# 262         0.1           0.2         Kodjia             0   Forward
# 19          0.3           0.9      Lacazette             0   Forward
# 285         0.2           0.5        Locadia             0   Forward
# 178         0.1           0.2     Martinelli             0   Forward
# 389         0.5           1.5         Maupay             0   Forward
# 396         0.5           1.4       McBurnie             0   Forward
# 127         0.3           0.9     McGoldrick             0   Forward
# 186         0.3           0.8         Murray             0   Forward
# 523         0.1           0.4           Muto             0   Forward
# 368         0.1           0.2        Obafemi             0   Forward
# 140         0.8           2.3          Origi             0   Forward
# 487         1.7           5.1          Pukki             0   Forward
# 334         0.7           2.2       Rashford             0   Forward
# 240         0.2           0.5      Rodriguez             0   Forward
# 72          0.5           1.5          Sharp             0   Forward
# 144         0.2           0.6        Solanke             0   Forward
# 137         0.1           0.2         Srbeny             0   Forward
# 208         0.1           0.2        Success             0   Forward
# 234         0.4           1.3          Vardy             0   Forward
# 118         0.1           0.3        Welbeck             0   Forward
# 510         0.7           2.2         Wesley             0   Forward
# 102         0.2           0.4        Wickham             0   Forward
# 99          0.3           0.9           Wood             0   Forward
#
#      minutes_points  web_name_lower  achievements    errors     value
# 485        3.733333         abraham      3.911111  0.333333  3.577778
# 88         4.844444           adams      1.614815  0.000000  1.614815
# 468        3.911111          agüero      6.637037  0.000000  6.637037
# 171        1.577778          andone      1.859259  1.000000  0.859259
# 420        6.000000      aubameyang      5.666667  0.333333  5.333333
# 265        3.066667            ayew      2.355556  0.000000  2.355556
# 49         5.555556          barnes      7.185185  0.333333  6.851852
# 90         4.155556         benteke      1.385185  0.000000  1.385185
# 78         5.488889   callum wilson      4.829630  0.000000  4.829630
# 143        5.088889   calvert-lewin      1.696296  0.333333  1.362963
# 238        2.355556      chicharito      2.118519  0.000000  2.118519
# 405        0.333333         cutrone      0.111111  0.000000  0.111111
# 498        4.000000          deeney      1.333333  0.000000  1.333333
# 184        4.355556        deulofeu      1.451852  0.000000  1.451852
# 274        0.155556           drmic      0.051852  0.000000  0.051852
# 438        5.777778         firmino      4.259259  0.000000  4.259259
# 399        2.222222          giroud      0.740741  0.000000  0.740741
# 31         3.800000            gray      2.600000  0.000000  2.600000
# 347        0.866667       greenwood      0.288889  0.000000  0.288889
# 483        4.000000          haller      4.000000  0.000000  4.000000
# 115        3.866667            ings      3.622222  0.000000  3.622222
# 177        2.044444           jesus      2.014815  0.000000  2.014815
# 428        6.000000         jiménez      3.333333  0.000000  3.333333
# 249        5.400000       joelinton      3.133333  0.666667  2.466667
# 139        5.555556            jota      1.851852  0.000000  1.851852
# 192        6.000000            kane      4.666667  0.000000  4.666667
# 376        1.488889            kean      0.496296  0.000000  0.496296
# 273        6.000000            king      3.333333  0.000000  3.333333
# 262        0.355556          kodjia      0.118519  0.000000  0.118519
# 19         1.755556       lacazette      1.918519  0.000000  1.918519
# 285        1.888889         locadia      0.629630  0.000000  0.629630
# 178        0.133333      martinelli      0.044444  0.000000  0.044444
# 389        2.711111          maupay      2.237037  0.000000  2.237037
# 396        2.155556        mcburnie      2.051852  0.000000  2.051852
# 127        4.511111      mcgoldrick      1.503704  0.000000  1.503704
# 186        3.377778          murray      1.125926  0.000000  1.125926
# 523        0.555556            muto      0.185185  0.000000  0.185185
# 368        0.533333         obafemi      0.177778  0.000000  0.177778
# 140        1.866667           origi      2.955556  0.000000  2.955556
# 487        5.822222           pukki      9.607407  0.000000  9.607407
# 334        5.844444        rashford      5.614815  0.666667  4.948148
# 240        1.044444       rodriguez      0.348148  0.000000  0.348148
# 72         0.977778           sharp      1.659259  0.000000  1.659259
# 144        0.800000         solanke      0.266667  0.000000  0.266667
# 137        0.200000          srbeny      0.066667  0.000000  0.066667
# 208        0.333333         success      0.111111  0.000000  0.111111
# 234        6.000000           vardy      3.333333  0.000000  3.333333
# 118        0.866667         welbeck      0.288889  0.000000  0.288889
# 510        5.622222          wesley      3.207407  0.000000  3.207407
# 102        0.333333         wickham      0.111111  0.000000  0.111111
# 99         5.333333            wood      1.777778  0.000000  1.777778
#
# [51 rows x 200 columns]
